# %% [markdown]
# #### Import packages

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %% [markdown]
# #### Import Floor Area csv file

# %%
FA_data = pd.read_csv('/Users/akihi/Library/CloudStorage/OneDrive-PrincetonUniversity/Projects/Building Material in Cities/1st Research/Code/Separated Code/Floor Area/Merged.csv')
print(FA_data)
# Out:
#                  Scenario      N_HH     N_SF   Avg_FA_SF  Total_FA_SF  \
# 0                BAU 2018  118449.0  57801.0  131.530000  7602565.530
# 1                BAU 2020       0.0  57854.0  132.766000  7681044.164
# 2                BAU 2040  137400.0  58384.0  145.090000  8470934.560
# 3            Compact City       0.0  58092.5  145.090000  8428640.825
# 4        Effective Design       0.0  58384.0  145.090000  8470934.560
# 5           Intensive Use       0.0  58384.0  131.723142  7690523.906
# 6             Mass-Timber       0.0  58384.0  145.090000  8470934.560
# 7      Alternative Cement       0.0  58384.0  145.090000  8470934.560
# 8        '+ Effective Use       0.0  58092.5  145.090000  8428640.825
# 9        '+ Intensive Use       0.0  58092.5  131.627055  7646544.718
# 10         '+ Mass-Timber       0.0  58092.5  131.627055  7646544.718
# 11  '+ Alternative Cement       0.0  58092.5  131.627055  7646544.718
#
# ...

# %% [markdown]
# ### Get ready for MFA

# %%
FA_data
# Out:
#                  Scenario      N_HH     N_SF   Avg_FA_SF  Total_FA_SF  \
# 0                BAU 2018  118449.0  57801.0  131.530000  7602565.530
# 1                BAU 2020       0.0  57854.0  132.766000  7681044.164
# 2                BAU 2040  137400.0  58384.0  145.090000  8470934.560
# 3            Compact City       0.0  58092.5  145.090000  8428640.825
# 4        Effective Design       0.0  58384.0  145.090000  8470934.560
# 5           Intensive Use       0.0  58384.0  131.723142  7690523.906
# 6             Mass-Timber       0.0  58384.0  145.090000  8470934.560
# 7      Alternative Cement       0.0  58384.0  145.090000  8470934.560
# 8        '+ Effective Use       0.0  58092.5  145.090000  8428640.825
# 9        '+ Intensive Use       0.0  58092.5  131.627055  7646544.718
# 10         '+ Mass-Timber       0.0  58092.5  131.627055  7646544.718
# 11  '+ Alternative Cement       0.0  58092.5  131.627055  7646544.718
#
# ...

# %%
# check the current row labels
FA_data.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
# check the current column labels
FA_data.columns
# Out:
# Index(['Scenario', 'N_HH', 'N_SF', 'Avg_FA_SF', 'Total_FA_SF', 'N_MF',
#        'Avg_FA_MF', 'Total_FA_MF', 'Total_FA_MRMF', 'Total_FA_HRMF',
#        'Conv_Total_FA_SF', 'Conv_Total_FA_LFSF', 'Conv_Total_FA_RCSF',
#        'Conv_Total_FA_MF', 'Conv_Total_FA_MRMF', 'Conv_Total_FA_HRMF',
#        'Avg_FA_New_SF', 'Avg_FA_New_MF', 'Total_FA_New_SF', 'Total_FA_New_MF',
#        'Total_FA_New_MRMF', 'Total_FA_New_HRMF', 'Conv_Total_FA_New_SF',
#        'Conv_Total_FA_New_LFSF', 'Conv_Total_FA_New_RCSF',
#        'Conv_Total_FA_New_MF', 'Conv_Total_FA_New_MRMF',
#        'Conv_Total_FA_New_HRMF', 'Total_FA_extended', 'Total_FA_extended_LF',
#        'Total_FA_extended_RC', 'MT_Total_FA_MF', 'MT_Total_FA_MRMF',
#        'MT_Total_FA_HRMF', 'AC_Total_FA_MF', 'AC_Total_FA_MRMF',
#        'AC_Total_FA_HRMF', 'Total_FA_Dem', 'Total_FA_Dem_SF',
#        'Total_FA_Dem_LFSF', 'Total_FA_Dem_RCSF', 'Total_FA_Dem_MRMF',
#        'Total_FA_Dem_HRMF', 'New_FA_LF', 'New_FA_RC', 'New_FA_MT',
# ...

# %%
# Assign 'Scenario' column values to row labels
FA_data.index = FA_data['Scenario']
FA_data.index
# Out:
# Index(['BAU 2018', 'BAU 2020', 'BAU 2040', 'Compact City', 'Effective Design',
#        'Intensive Use', 'Mass-Timber', 'Alternative Cement',
#        ''+ Effective Use', ''+ Intensive Use', ''+ Mass-Timber',
#        ''+ Alternative Cement'],
#       dtype='object', name='Scenario')

# %%
FA_data.loc['BAU 2018', 'N_HH']
# Out:
# 118449.0

# %% [markdown]
# #### Import FA Base Variable

# %%
# Read the input variable
FA_variable = pd.read_csv('/Users/akihi/Library/CloudStorage/OneDrive-PrincetonUniversity/Projects/Building Material in Cities/1st Research/Code/Separated Code/Input/Input variables.csv', skiprows=1)
# Display the data
print(FA_variable)
# Out:
#    SF_LF  SF_RC  MF_MR  new_MF_MR  MF_LF  MT_2018  MF_HR_RC  Num_dem  SF_dem  \
# 0   0.92   0.08   0.92       0.92      1        0         1     64.5    0.43
#
#    SC_Compact_SF_to_MF  SC_MT_new_MRMF_to_MT  SC_MT_new_HRMF_to_MT  \
# 0                  0.5                   0.5                     0
#
#    SC_AC_new_MRMF_to_AC  SC_AC_new_HRMF_to_AC  SC_IU  SC_EU
# 0                   0.5                     0    0.2   0.19

# %%
# Assign values to variables
SF_LF = FA_variable['SF_LF'][0]
MF_MR = FA_variable['MF_MR'][0]
new_MF_MR = FA_variable['new_MF_MR'][0]
MF_LF = FA_variable['MF_LF'][0]
MT_2018 = FA_variable['MT_2018'][0]
MF_HR_RC = FA_variable['MF_HR_RC'][0]
Num_dem = FA_variable['Num_dem'][0]
SF_dem = FA_variable['SF_dem'][0]
SC_Compact_SF_to_MF = FA_variable['SC_Compact_SF_to_MF'][0]
SC_MT_new_MRMF_to_MT = FA_variable['SC_MT_new_MRMF_to_MT'][0]
SC_MT_new_HRMF_to_MT = FA_variable['SC_MT_new_HRMF_to_MT'][0]
SC_AC_new_MRMF_to_AC = FA_variable['SC_AC_new_MRMF_to_AC'][0]
SC_AC_new_HRMF_to_AC = FA_variable['SC_AC_new_HRMF_to_AC'][0]
SC_IU = FA_variable['SC_IU'][0]
SC_EU = FA_variable['SC_EU'][0]

# %% [markdown]
# #### Import Material Intensity

# %%
# Read the input variable
Material_Intensity = pd.read_csv('/Users/akihi/Library/CloudStorage/OneDrive-PrincetonUniversity/Projects/Building Material in Cities/1st Research/Code/Separated Code/Input/Material Intensity.csv', skiprows=1)

# Assign values to variables
MI_Con_LF = Material_Intensity['LF'][0]
MI_Con_RC = Material_Intensity['RC'][0]
MI_Con_MT = Material_Intensity['MT'][0]
MI_Iron_LF = Material_Intensity['LF'][1]
MI_Iron_RC = Material_Intensity['RC'][1]
MI_Iron_MT = Material_Intensity['MT'][1]
MI_Wood_LF = Material_Intensity['LF'][2]
MI_Wood_RC = Material_Intensity['RC'][2]
MI_Wood_MT = Material_Intensity['MT'][2]
MI_Wood_no_CLT_LF = Material_Intensity['LF'][3]
MI_Wood_no_CLT_RC = Material_Intensity['RC'][3]
MI_Wood_no_CLT_MT = Material_Intensity['MT'][3]
MI_CLT_LF = Material_Intensity['LF'][4]
MI_CLT_RC = Material_Intensity['RC'][4]
MI_CLT_MT = Material_Intensity['MT'][4]

# %% [markdown]
# #### Import Maerial Intesnsity for Construction Waste

# %%
# Read the input variable
MI_Construction = pd.read_csv('/Users/akihi/Library/CloudStorage/OneDrive-PrincetonUniversity/Projects/Building Material in Cities/1st Research/Code/Separated Code/Input/MI for Construction Waste.csv', skiprows=1)
# Assign values to variables
MI_Waste_Con_LF = MI_Construction['LF'][0]
MI_Waste_Con_RC = MI_Construction['RC'][0]
MI_Waste_Iron_LF = MI_Construction['LF'][1]
MI_Waste_Iron_RC = MI_Construction['RC'][1]
MI_Waste_Wood_LF = MI_Construction['LF'][2]
MI_Waste_Wood_RC = MI_Construction['RC'][2]

MI_Construction
# Out:
#      Material       LF      RC
# 0    Concrete  0.00026  0.0229
# 1  Iron/Steel  0.00030  0.0009
# 2        Wood  0.01200  0.0064

# %% [markdown]
# #### Import Next Use Rate

# %%
Next_Use = pd.read_csv('/Users/akihi/Library/CloudStorage/OneDrive-PrincetonUniversity/Projects/Building Material in Cities/1st Research/Code/Separated Code/Input/Next Use.csv', skiprows=1)

NU_Con = Next_Use['Next_Use_Con'][0]
NU_Iron = Next_Use['Next_Use_Iron'][0]
NU_Wood = Next_Use['Next_Use_Wood'][0]

# %% [markdown]
# #### Import Concrete Mix

# %%
# Read the input variable
Concrete_Mix = pd.read_csv('/Users/akihi/Library/CloudStorage/OneDrive-PrincetonUniversity/Projects/Building Material in Cities/1st Research/Code/Separated Code/Input/Concrete Mix.csv')

Cement_Mix = Concrete_Mix['Percentage'][0]
Aggregate_Mix = Concrete_Mix['Percentage'][1]
Water_Mix = Concrete_Mix['Percentage'][2]

# %% [markdown]
# ## Material Stock

# %%
# Prepare the dataframe
column = {'BAU2018_SF': [], 'BAU2018_MF': [], 'BAU2018_Total': [],\
      'BAU2020_SF': [], 'BAU2020_MF': [], 'BAU2020_Total': [], \
       'BAU2040_SF': [], 'BAU2040_MF': [], 'BAU2040_Total': [], \
        'Compact_City_SF': [], 'Compact_City_MF': [], 'Compact_City_Total': [], \
         'Effective_Design_SF': [], 'Effective_Design_MF': [], 'Effective_Design_Total': [], \
            'Intensive_Use_SF': [], 'Intensive_Use_MF': [], 'Intensive_Use_Total': [], \
             'Mass_Timber_SF': [], 'Mass_Timber_MF': [], 'Mass_Timber_Total': [], \
               'Alternative_Cement_SF': [], 'Alternative_Cement_MF': [], 'Alternative_Cement_Total': [], \
                "'+ Effective_Design_SF": [], "'+ Effective_Design_MF": [], "'+ Effective_Design_Total": [], \
                  "'+ Intensive_Use_SF": [], "'+ Intensive_Use_MF": [], "'+ Intensive_Use_Total": [], \
                    "'+ Mass_Timber_SF": [], "'+ Mass_Timber_MF": [], "'+ Mass_Timber_Total": [], \
                      "'+ Alternative_Cement_SF": [], "'+ Alternative_Cement_MF": [], "'+ Alternative_Cement_Total": []}
index = ['Concrete (w/ PC)', 'Iron/Steel', 'Wood (Total)', 'Wood (except CLT)', 'CLT', 'PC', 'Concrete (w/ AC)', 'AC',
         'Total (Concrete+Iron+Wood)', 'Total (PC+Iron+Wood)', 'Total (PC+AC+Iron+Wood)']

MS_data = pd.DataFrame(index=index, columns=column.keys())
MS_data = MS_data.fillna(0)

# %%
# print the data w/o omitting
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Change NaN to zero
FA_data = FA_data.fillna(0)

# %% [markdown]
# ### SF

# %%
# Make a loop for SF

for scenario in ['BAU2018_SF', 'BAU2020_SF', 'BAU2040_SF', 'Compact_City_SF','Intensive_Use_SF', 'Mass_Timber_SF', 'Alternative_Cement_SF']:
    if scenario == 'BAU2018_SF':
        base_scenario = 'BAU 2018'
    elif scenario == 'BAU2020_SF':
        base_scenario = 'BAU 2020'
    elif scenario == 'BAU2040_SF':
        base_scenario = 'BAU 2040'
    elif scenario == 'Compact_City_SF':
        base_scenario = 'Compact City'
    elif scenario == 'Intensive_Use_SF':
        base_scenario = 'Intensive Use'
    elif scenario == 'Mass_Timber_SF':
        base_scenario = 'Mass-Timber'
    elif scenario == 'Alternative_Cement_SF':
        base_scenario = 'Alternative Cement'

    MS_data.loc['Concrete (w/ PC)', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_LFSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_LFSF']) * MI_Con_LF + (FA_data.loc[base_scenario, 'Conv_Total_FA_RCSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_RCSF']) * MI_Con_RC
    MS_data.loc['Iron/Steel', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_LFSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_LFSF']) * MI_Iron_LF + (FA_data.loc[base_scenario, 'Conv_Total_FA_RCSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_RCSF']) * MI_Iron_RC
    MS_data.loc['Wood (Total)', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_LFSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_LFSF']) * MI_Wood_LF + (FA_data.loc[base_scenario, 'Conv_Total_FA_RCSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_RCSF']) * MI_Wood_RC
    MS_data.loc['Wood (except CLT)', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_LFSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_LFSF']) * MI_Wood_no_CLT_LF + (FA_data.loc[base_scenario, 'Conv_Total_FA_RCSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_RCSF']) * MI_Wood_no_CLT_RC
    MS_data.loc['CLT', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_LFSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_LFSF']) * MI_CLT_LF + (FA_data.loc[base_scenario, 'Conv_Total_FA_RCSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_RCSF']) * MI_CLT_RC
    MS_data.loc['PC', scenario] = MS_data.loc['Concrete (w/ PC)', scenario] * Cement_Mix

    MS_data.loc['Total (Concrete+Iron+Wood)', scenario] = MS_data.loc['Concrete (w/ PC)', scenario] + MS_data.loc['Iron/Steel', scenario] + MS_data.loc['Wood (Total)', scenario]
    MS_data.loc['Total (PC+Iron+Wood)', scenario] = MS_data.loc['PC', scenario] + MS_data.loc['Iron/Steel', scenario] + MS_data.loc['Wood (Total)', scenario]
    MS_data.loc['Total (PC+AC+Iron+Wood)', scenario] =  MS_data.loc['PC', scenario] + MS_data.loc['Iron/Steel', scenario] + MS_data.loc['Wood (Total)', scenario] + MS_data.loc['AC', scenario]


MS_data
# Out:
#                               BAU2018_SF  BAU2018_MF  BAU2018_Total  \
# Concrete (w/ PC)            2.149525e+06           0              0
# Iron/Steel                  1.115043e+05           0              0
# Wood (Total)                7.119736e+05           0              0
# Wood (except CLT)           7.119736e+05           0              0
# CLT                         0.000000e+00           0              0
# PC                          2.708402e+05           0              0
# Concrete (w/ AC)            0.000000e+00           0              0
# AC                          0.000000e+00           0              0
# Total (Concrete+Iron+Wood)  2.973003e+06           0              0
# Total (PC+Iron+Wood)        1.094318e+06           0              0
# Total (PC+AC+Iron+Wood)     1.094318e+06           0              0
#
#                               BAU2020_SF  BAU2020_MF  BAU2020_Total  \
# Concrete (w/ PC)            2.152351e+06           0              0
# ...

# %%
# Effective Design

MS_data.loc['Concrete (w/ PC)', 'Effective_Design_SF'] = (FA_data.loc['Effective Design', 'Conv_Total_FA_LFSF'] * MI_Con_LF + FA_data.loc['Effective Design', 'Conv_Total_FA_New_LFSF']* MI_Con_LF * (1 - SC_EU)) + (FA_data.loc['Effective Design', 'Conv_Total_FA_RCSF'] * MI_Con_RC + FA_data.loc['Effective Design', 'Conv_Total_FA_New_RCSF'] * MI_Con_RC * (1 - SC_EU))
MS_data.loc['Iron/Steel', 'Effective_Design_SF'] =  (FA_data.loc['Effective Design', 'Conv_Total_FA_LFSF'] + FA_data.loc['Effective Design', 'Conv_Total_FA_New_LFSF']) * MI_Iron_LF + (FA_data.loc['Effective Design', 'Conv_Total_FA_RCSF'] + FA_data.loc['Effective Design', 'Conv_Total_FA_New_RCSF']) * MI_Iron_RC
MS_data.loc['Wood (Total)', 'Effective_Design_SF'] =  (FA_data.loc['Effective Design', 'Conv_Total_FA_LFSF'] + FA_data.loc['Effective Design', 'Conv_Total_FA_New_LFSF']) * MI_Wood_LF + (FA_data.loc['Effective Design', 'Conv_Total_FA_RCSF'] + FA_data.loc['Effective Design', 'Conv_Total_FA_New_RCSF']) * MI_Wood_RC
MS_data.loc['Wood (except CLT)', 'Effective_Design_SF'] =  (FA_data.loc['Effective Design', 'Conv_Total_FA_LFSF'] + FA_data.loc['Effective Design', 'Conv_Total_FA_New_LFSF']) * MI_Wood_no_CLT_LF + (FA_data.loc['Effective Design', 'Conv_Total_FA_RCSF'] + FA_data.loc['Effective Design', 'Conv_Total_FA_New_RCSF']) * MI_Wood_no_CLT_RC
MS_data.loc['CLT', 'Effective_Design_SF'] =  (FA_data.loc['Effective Design', 'Conv_Total_FA_LFSF'] + FA_data.loc['Effective Design', 'Conv_Total_FA_New_LFSF']) * MI_CLT_LF + (FA_data.loc['Effective Design', 'Conv_Total_FA_RCSF'] + FA_data.loc['Effective Design', 'Conv_Total_FA_New_RCSF']) * MI_CLT_RC
MS_data.loc['PC', 'Effective_Design_SF'] =  MS_data.loc['Concrete (w/ PC)', 'Effective_Design_SF'] * Cement_Mix

MS_data.loc['Total (Concrete+Iron+Wood)', 'Effective_Design_SF'] =  MS_data.loc['Concrete (w/ PC)', 'Effective_Design_SF'] + MS_data.loc['Iron/Steel', 'Effective_Design_SF'] + MS_data.loc['Wood (Total)', 'Effective_Design_SF']
MS_data.loc['Total (PC+Iron+Wood)', 'Effective_Design_SF'] =  MS_data.loc['PC', 'Effective_Design_SF'] + MS_data.loc['Iron/Steel', 'Effective_Design_SF'] + MS_data.loc['Wood (Total)', 'Effective_Design_SF']
MS_data.loc['Total (PC+AC+Iron+Wood)', 'Effective_Design_SF'] =  MS_data.loc['PC', 'Effective_Design_SF'] + MS_data.loc['Iron/Steel', 'Effective_Design_SF'] + MS_data.loc['Wood (Total)', 'Effective_Design_SF'] + MS_data.loc['AC', 'Effective_Design_SF']

MS_data.loc[:, 'Effective_Design_SF']
# Out:
# Concrete (w/ PC)              2.174705e+06
# Iron/Steel                    1.131169e+05
# Wood (Total)                  7.222701e+05
# Wood (except CLT)             7.222701e+05
# CLT                           0.000000e+00
# PC                            2.740129e+05
# Concrete (w/ AC)              0.000000e+00
# AC                            0.000000e+00
# Total (Concrete+Iron+Wood)    3.010092e+06
# Total (PC+Iron+Wood)          1.109400e+06
# Total (PC+AC+Iron+Wood)       1.109400e+06
# Name: Effective_Design_SF, dtype: float64

# %%
# Make a loop for SF when scenarios are multiplicative & Effective Design Case

for scenario in ['Effective_Design_SF', "'+ Effective_Design_SF", "'+ Intensive_Use_SF", "'+ Mass_Timber_SF", "'+ Alternative_Cement_SF"]:
    if scenario == 'Effective_Design_SF':
        base_scenario = 'Effective Design'
    elif scenario == "'+ Effective_Design_SF":
        base_scenario = "'+ Effective Use"
    elif scenario == "'+ Intensive_Use_SF":
        base_scenario = "'+ Intensive Use"
    elif scenario == "'+ Mass_Timber_SF":
        base_scenario = "'+ Mass-Timber"
    elif scenario == '+ + Alternative_Cement_SF':
        base_scenario = "'+ Alternative Cement"

    MS_data.loc['Concrete (w/ PC)', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_LFSF'] * MI_Con_LF + FA_data.loc[base_scenario, 'Conv_Total_FA_New_LFSF'] * MI_Con_LF * (1 - SC_EU)) + (FA_data.loc[base_scenario, 'Conv_Total_FA_RCSF'] * MI_Con_RC + FA_data.loc[base_scenario, 'Conv_Total_FA_New_RCSF'] * MI_Con_RC * (1 - SC_EU))
    MS_data.loc['Iron/Steel', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_LFSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_LFSF']) * MI_Iron_LF + (FA_data.loc[base_scenario, 'Conv_Total_FA_RCSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_RCSF']) * MI_Iron_RC
    MS_data.loc['Wood (Total)', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_LFSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_LFSF']) * MI_Wood_LF + (FA_data.loc[base_scenario, 'Conv_Total_FA_RCSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_RCSF']) * MI_Wood_RC
    MS_data.loc['Wood (except CLT)', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_LFSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_LFSF']) * MI_Wood_no_CLT_LF + (FA_data.loc[base_scenario, 'Conv_Total_FA_RCSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_RCSF']) * MI_Wood_no_CLT_RC
    MS_data.loc['CLT', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_LFSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_LFSF']) * MI_CLT_LF + (FA_data.loc[base_scenario, 'Conv_Total_FA_RCSF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_RCSF']) * MI_CLT_RC
    MS_data.loc['PC', scenario] = MS_data.loc['Concrete (w/ PC)', scenario] * Cement_Mix

    MS_data.loc['Total (Concrete+Iron+Wood)', scenario] = MS_data.loc['Concrete (w/ PC)', scenario] + MS_data.loc['Iron/Steel', scenario] + MS_data.loc['Wood (Total)', scenario]
    MS_data.loc['Total (PC+Iron+Wood)', scenario] = MS_data.loc['PC', scenario] + MS_data.loc['Iron/Steel', scenario] + MS_data.loc['Wood (Total)', scenario]
    MS_data.loc['Total (PC+AC+Iron+Wood)', scenario] =  MS_data.loc['PC', scenario] + MS_data.loc['Iron/Steel', scenario] + MS_data.loc['Wood (Total)', scenario] + MS_data.loc['AC', scenario]


MS_data
# Out:
#                               BAU2018_SF  BAU2018_MF  BAU2018_Total  \
# Concrete (w/ PC)            2.149525e+06           0              0
# Iron/Steel                  1.115043e+05           0              0
# Wood (Total)                7.119736e+05           0              0
# Wood (except CLT)           7.119736e+05           0              0
# CLT                         0.000000e+00           0              0
# PC                          2.708402e+05           0              0
# Concrete (w/ AC)            0.000000e+00           0              0
# AC                          0.000000e+00           0              0
# Total (Concrete+Iron+Wood)  2.973003e+06           0              0
# Total (PC+Iron+Wood)        1.094318e+06           0              0
# Total (PC+AC+Iron+Wood)     1.094318e+06           0              0
#
#                               BAU2020_SF  BAU2020_MF  BAU2020_Total  \
# Concrete (w/ PC)            2.152351e+06           0              0
# ...

# %% [markdown]
# ### MF

# %%
# Make a loop for MF
for scenario in ['BAU2018_MF', 'BAU2020_MF', 'BAU2040_MF', 'Compact_City_MF', 'Intensive_Use_MF']:
    if scenario == 'BAU2018_MF':
        base_scenario = 'BAU 2018'
    elif scenario == 'BAU2020_MF':
        base_scenario = 'BAU 2020'
    elif scenario == 'BAU2040_MF':
        base_scenario = 'BAU 2040'
    elif scenario == 'Compact_City_MF':
        base_scenario = 'Compact City'
    elif scenario == 'Intensive_Use_MF':
        base_scenario = 'Intensive Use'

    
    MS_data.loc['Concrete (w/ PC)', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_MRMF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_MRMF']) * MI_Con_LF + (FA_data.loc[base_scenario, 'Conv_Total_FA_HRMF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_HRMF']) * MI_Con_RC
    MS_data.loc['Iron/Steel', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_MRMF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_MRMF']) * MI_Iron_LF + (FA_data.loc[base_scenario, 'Conv_Total_FA_HRMF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_HRMF']) * MI_Iron_RC
    MS_data.loc['Wood (Total)', scenario] =  (FA_data.loc[base_scenario, 'Conv_Total_FA_MRMF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_MRMF']) * MI_Wood_LF + (FA_data.loc[base_scenario, 'Conv_Total_FA_HRMF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_HRMF']) * MI_Wood_RC
    MS_data.loc['Wood (except CLT)', scenario] =  (FA_data.loc[base_scenario, 'Conv_Total_FA_MRMF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_MRMF']) * MI_Wood_no_CLT_LF + (FA_data.loc[base_scenario, 'Conv_Total_FA_HRMF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_HRMF']) * MI_Wood_no_CLT_RC
    MS_data.loc['CLT', scenario] =  (FA_data.loc[base_scenario, 'Conv_Total_FA_MRMF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_MRMF']) * MI_CLT_LF+ (FA_data.loc[base_scenario, 'Conv_Total_FA_HRMF'] + FA_data.loc[base_scenario, 'Conv_Total_FA_New_HRMF']) * MI_CLT_RC
    MS_data.loc['PC', scenario] = MS_data.loc['Concrete (w/ PC)', scenario] * Cement_Mix
    MS_data.loc['Total (Concrete+Iron+Wood)', scenario] = MS_data.loc['Concrete (w/ PC)', scenario] + MS_data.loc['Iron/Steel', scenario] + MS_data.loc['Wood (Total)', scenario]
    MS_data.loc['Total (PC+Iron+Wood)', scenario] = MS_data.loc['PC', scenario] + MS_data.loc['Iron/Steel', scenario] + MS_data.loc['Wood (Total)', scenario]
    MS_data.loc['Total (PC+AC+Iron+Wood)', scenario] =  MS_data.loc['PC', scenario] + MS_data.loc['Iron/Steel', scenario] + MS_data.loc['Wood (Total)', scenario] + MS_data.loc['AC', scenario]

# %%
# Make a loop for MF when scenarios are multiplicative & Effective Design Case

for scenario in ['Effective_Design_MF', "'+ Effective_Design_MF", "'+ Intensive_Use_MF"]:
    if scenario == 'Effective_Design_MF':
        base_scenario = 'Effective Design'
    elif scenario == "'+ Effective_Design_MF":
        base_scenario = "'+ Effective Use"
    elif scenario == "'+ Intensive_Use_MF":
        base_scenario = "'+ Intensive Use"

    MS_data.loc['Concrete (w/ PC)', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_MRMF'] * MI_Con_LF + FA_data.loc[base_scenario, 'Conv_Total_FA_HRMF'] * MI_Con_RC) + (FA_data.loc[base_scenario, 'Total_FA_New_MRMF'] * MI_Con_LF + FA_data.loc[base_scenario, 'Total_FA_New_HRMF'] * MI_Con_RC) * (1 - SC_EU)
    MS_data.loc['Iron/Steel', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_MRMF'] * MI_Iron_LF + FA_data.loc[base_scenario, 'Conv_Total_FA_HRMF'] * MI_Iron_RC) + (FA_data.loc[base_scenario, 'Total_FA_New_MRMF'] * MI_Iron_LF + FA_data.loc[base_scenario, 'Total_FA_New_HRMF'] * MI_Iron_RC)
    MS_data.loc['Wood (Total)', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_MRMF'] * MI_Wood_LF + FA_data.loc[base_scenario, 'Conv_Total_FA_HRMF'] * MI_Wood_RC) + (FA_data.loc[base_scenario, 'Total_FA_New_MRMF'] * MI_Wood_LF + FA_data.loc[base_scenario, 'Total_FA_New_HRMF'] * MI_Wood_RC)
    MS_data.loc['Wood (except CLT)', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_MRMF'] * MI_Wood_no_CLT_LF + FA_data.loc[base_scenario, 'Conv_Total_FA_HRMF'] * MI_Wood_no_CLT_RC) + (FA_data.loc[base_scenario, 'Total_FA_New_MRMF'] * MI_Wood_no_CLT_LF + FA_data.loc[base_scenario, 'Total_FA_New_HRMF'] * MI_Wood_no_CLT_RC)
    MS_data.loc['CLT', scenario] = (FA_data.loc[base_scenario, 'Conv_Total_FA_MRMF'] * MI_CLT_LF + FA_data.loc[base_scenario, 'Conv_Total_FA_HRMF'] * MI_CLT_RC) + (FA_data.loc[base_scenario, 'Total_FA_New_MRMF'] * MI_CLT_LF + FA_data.loc[base_scenario, 'Total_FA_New_HRMF'] * MI_CLT_RC)
    MS_data.loc['PC', scenario] = MS_data.loc['Concrete (w/ PC)', scenario] * Cement_Mix

    MS_data.loc['Total (Concrete+Iron+Wood)', scenario] = MS_data.loc['Concrete (w/ PC)', scenario] + MS_data.loc['Iron/Steel', scenario] + MS_data.loc['Wood (Total)', scenario]
    MS_data.loc['Total (PC+Iron+Wood)', scenario] = MS_data.loc['PC', scenario] + MS_data.loc['Iron/Steel', scenario] + MS_data.loc['Wood (Total)', scenario]
    MS_data.loc['Total (PC+AC+Iron+Wood)', scenario] =  MS_data.loc['PC', scenario] + MS_data.loc['Iron/Steel', scenario] + MS_data.loc['Wood (Total)', scenario] + MS_data.loc['AC', scenario]

# %%
# Mass-Timber MF

MS_data.loc['Concrete (w/ PC)', 'Mass_Timber_MF'] = (FA_data.loc['Mass-Timber', 'Conv_Total_FA_MRMF'] + FA_data.loc['Mass-Timber', 'Conv_Total_FA_New_MRMF']) * MI_Con_LF + (FA_data.loc['Mass-Timber', 'Conv_Total_FA_HRMF'] + FA_data.loc['Mass-Timber', 'Conv_Total_FA_New_HRMF']) * MI_Con_RC + FA_data.loc['Mass-Timber', 'MT_Total_FA_MF'] * MI_Con_MT
MS_data.loc['Iron/Steel', 'Mass_Timber_MF'] = (FA_data.loc['Mass-Timber', 'Conv_Total_FA_MRMF'] + FA_data.loc['Mass-Timber', 'Conv_Total_FA_New_MRMF']) * MI_Iron_LF + (FA_data.loc['Mass-Timber', 'Conv_Total_FA_HRMF'] + FA_data.loc['Mass-Timber', 'Conv_Total_FA_New_HRMF']) * MI_Iron_RC + FA_data.loc['Mass-Timber', 'MT_Total_FA_MF'] * MI_Iron_MT
MS_data.loc['Wood (Total)', 'Mass_Timber_MF'] =  (FA_data.loc['Mass-Timber', 'Conv_Total_FA_MRMF'] + FA_data.loc['Mass-Timber', 'Conv_Total_FA_New_MRMF']) * MI_Wood_LF + (FA_data.loc['Mass-Timber', 'Conv_Total_FA_HRMF'] + FA_data.loc['Mass-Timber', 'Conv_Total_FA_New_HRMF']) * MI_Wood_RC + FA_data.loc['Mass-Timber', 'MT_Total_FA_MF'] * MI_Wood_MT
MS_data.loc['Wood (except CLT)', 'Mass_Timber_MF'] =  (FA_data.loc['Mass-Timber', 'Conv_Total_FA_MRMF'] + FA_data.loc['Mass-Timber', 'Conv_Total_FA_New_MRMF']) * MI_Wood_no_CLT_LF + (FA_data.loc['Mass-Timber', 'Conv_Total_FA_HRMF'] + FA_data.loc['Mass-Timber', 'Conv_Total_FA_New_HRMF']) * MI_Wood_no_CLT_RC + FA_data.loc['Mass-Timber', 'MT_Total_FA_MF'] * MI_Wood_no_CLT_MT
MS_data.loc['CLT', 'Mass_Timber_MF'] =  (FA_data.loc['Mass-Timber', 'Conv_Total_FA_MRMF'] + FA_data.loc['Mass-Timber', 'Conv_Total_FA_New_MRMF']) * MI_CLT_LF+ (FA_data.loc['Mass-Timber', 'Conv_Total_FA_HRMF'] + FA_data.loc['Mass-Timber', 'Conv_Total_FA_New_HRMF']) * MI_CLT_RC + FA_data.loc['Mass-Timber', 'MT_Total_FA_MF'] * MI_CLT_MT
MS_data.loc['PC', 'Mass_Timber_MF'] = MS_data.loc['Concrete (w/ PC)', 'Mass_Timber_MF'] * Cement_Mix
MS_data.loc['Total (Concrete+Iron+Wood)', 'Mass_Timber_MF'] = MS_data.loc['Concrete (w/ PC)', 'Mass_Timber_MF'] + MS_data.loc['Iron/Steel', 'Mass_Timber_MF'] + MS_data.loc['Wood (Total)', 'Mass_Timber_MF']
MS_data.loc['Total (PC+Iron+Wood)', 'Mass_Timber_MF'] = MS_data.loc['PC', 'Mass_Timber_MF'] + MS_data.loc['Iron/Steel', 'Mass_Timber_MF'] + MS_data.loc['Wood (Total)', 'Mass_Timber_MF']
MS_data.loc['Total (PC+AC+Iron+Wood)', 'Mass_Timber_MF'] =  MS_data.loc['PC', 'Mass_Timber_MF'] + MS_data.loc['Iron/Steel', 'Mass_Timber_MF'] + MS_data.loc['Wood (Total)', 'Mass_Timber_MF'] + MS_data.loc['AC', 'Mass_Timber_MF']

# + Mass-Timber MF
MS_data.loc['Concrete (w/ PC)', "'+ Mass_Timber_MF"] = (FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_MRMF'] * MI_Con_LF + FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_HRMF'] * MI_Con_RC) + (FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_New_MRMF'] * MI_Con_LF + FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_New_HRMF'] * MI_Con_RC) * (1 - SC_EU) + FA_data.loc["'+ Mass-Timber", 'MT_Total_FA_MF'] * MI_Con_MT
MS_data.loc['Iron/Steel', "'+ Mass_Timber_MF"] = (FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_MRMF'] + FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_New_MRMF']) * MI_Iron_LF + (FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_HRMF'] + FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_New_HRMF']) * MI_Iron_RC + FA_data.loc["'+ Mass-Timber", 'MT_Total_FA_MF'] * MI_Iron_MT
MS_data.loc['Wood (Total)', "'+ Mass_Timber_MF"] =  (FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_MRMF'] + FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_New_MRMF']) * MI_Wood_LF + (FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_HRMF'] + FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_New_HRMF']) * MI_Wood_RC + FA_data.loc["'+ Mass-Timber", 'MT_Total_FA_MF'] * MI_Wood_MT
MS_data.loc['Wood (except CLT)', "'+ Mass_Timber_MF"] =  (FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_MRMF'] + FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_New_MRMF']) * MI_Wood_no_CLT_LF + (FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_HRMF'] + FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_New_HRMF']) * MI_Wood_no_CLT_RC + FA_data.loc["'+ Mass-Timber", 'MT_Total_FA_MF'] * MI_Wood_no_CLT_MT
MS_data.loc['CLT', "'+ Mass_Timber_MF"] =  (FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_MRMF'] + FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_New_MRMF']) * MI_CLT_LF+ (FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_HRMF'] + FA_data.loc["'+ Mass-Timber", 'Conv_Total_FA_New_HRMF']) * MI_CLT_RC + FA_data.loc["'+ Mass-Timber", 'MT_Total_FA_MF'] * MI_CLT_MT
MS_data.loc['PC', "'+ Mass_Timber_MF"] = MS_data.loc['Concrete (w/ PC)', "'+ Mass_Timber_MF"] * Cement_Mix
MS_data.loc['Total (Concrete+Iron+Wood)', "'+ Mass_Timber_MF"] = MS_data.loc['Concrete (w/ PC)', "'+ Mass_Timber_MF"] + MS_data.loc['Iron/Steel', "'+ Mass_Timber_MF"] + MS_data.loc['Wood (Total)', "'+ Mass_Timber_MF"]
MS_data.loc['Total (PC+Iron+Wood)', "'+ Mass_Timber_MF"] = MS_data.loc['PC', "'+ Mass_Timber_MF"] + MS_data.loc['Iron/Steel', "'+ Mass_Timber_MF"] + MS_data.loc['Wood (Total)', "'+ Mass_Timber_MF"]
MS_data.loc['Total (PC+AC+Iron+Wood)', "'+ Mass_Timber_MF"] =  MS_data.loc['PC', "'+ Mass_Timber_MF"] + MS_data.loc['Iron/Steel', "'+ Mass_Timber_MF"] + MS_data.loc['Wood (Total)', "'+ Mass_Timber_MF"] + MS_data.loc['AC', "'+ Mass_Timber_MF"]

# %%
# Alternative Cement MF

MS_data.loc['Concrete (w/ PC)', 'Alternative_Cement_MF'] = (FA_data.loc['Alternative Cement', 'Conv_Total_FA_MRMF'] + FA_data.loc['Alternative Cement', 'Conv_Total_FA_New_MRMF']) * MI_Con_LF + (FA_data.loc['Alternative Cement', 'Conv_Total_FA_HRMF'] + FA_data.loc['Alternative Cement', 'Conv_Total_FA_New_HRMF']) * MI_Con_RC
MS_data.loc['Iron/Steel', 'Alternative_Cement_MF'] = (FA_data.loc['Alternative Cement', 'Conv_Total_FA_MRMF'] + FA_data.loc['Alternative Cement', 'Conv_Total_FA_New_MRMF'] + FA_data.loc['Alternative Cement', 'AC_Total_FA_MRMF']) * MI_Iron_LF + (FA_data.loc['Alternative Cement', 'Conv_Total_FA_HRMF'] + FA_data.loc['Alternative Cement', 'Conv_Total_FA_New_HRMF'] + FA_data.loc['Alternative Cement', 'AC_Total_FA_HRMF']) * MI_Iron_RC
MS_data.loc['Wood (Total)', 'Alternative_Cement_MF'] =  (FA_data.loc['Alternative Cement', 'Conv_Total_FA_MRMF'] + FA_data.loc['Alternative Cement', 'Conv_Total_FA_New_MRMF'] + FA_data.loc['Alternative Cement', 'AC_Total_FA_MRMF']) * MI_Wood_LF + (FA_data.loc['Alternative Cement', 'Conv_Total_FA_HRMF'] + FA_data.loc['Alternative Cement', 'Conv_Total_FA_New_HRMF'] + FA_data.loc['Alternative Cement', 'AC_Total_FA_HRMF']) * MI_Wood_RC
MS_data.loc['Wood (except CLT)', 'Alternative_Cement_MF'] =  (FA_data.loc['Alternative Cement', 'Conv_Total_FA_MRMF'] + FA_data.loc['Alternative Cement', 'Conv_Total_FA_New_MRMF'] + FA_data.loc['Alternative Cement', 'AC_Total_FA_MRMF']) * MI_Wood_no_CLT_LF + (FA_data.loc['Alternative Cement', 'Conv_Total_FA_HRMF'] + FA_data.loc['Alternative Cement', 'Conv_Total_FA_New_HRMF'] + FA_data.loc['Alternative Cement', 'AC_Total_FA_HRMF']) * MI_Wood_no_CLT_RC
MS_data.loc['CLT', 'Alternative_Cement_MF'] =  (FA_data.loc['Alternative Cement', 'Conv_Total_FA_MRMF'] + FA_data.loc['Alternative Cement', 'Conv_Total_FA_New_MRMF'] + FA_data.loc['Alternative Cement', 'AC_Total_FA_MRMF']) * MI_CLT_LF+ (FA_data.loc['Alternative Cement', 'Conv_Total_FA_HRMF'] + FA_data.loc['Alternative Cement', 'Conv_Total_FA_New_HRMF'] + FA_data.loc['Alternative Cement', 'AC_Total_FA_HRMF']) * MI_CLT_RC
MS_data.loc['PC', 'Alternative_Cement_MF'] = MS_data.loc['Concrete (w/ PC)', 'Alternative_Cement_MF'] * Cement_Mix
MS_data.loc['Concrete (w/ AC)', 'Alternative_Cement_MF'] = FA_data.loc['Alternative Cement', 'AC_Total_FA_MRMF'] * MI_Con_LF + FA_data.loc['Alternative Cement', 'AC_Total_FA_HRMF'] * MI_Con_RC
MS_data.loc['AC', 'Alternative_Cement_MF'] = MS_data.loc['Concrete (w/ AC)', 'Alternative_Cement_MF'] * Cement_Mix
MS_data.loc['Total (Concrete+Iron+Wood)', 'Alternative_Cement_MF'] = MS_data.loc['Concrete (w/ PC)', 'Alternative_Cement_MF'] + MS_data.loc['Iron/Steel', 'Alternative_Cement_MF'] + MS_data.loc['Wood (Total)', 'Alternative_Cement_MF']
MS_data.loc['Total (PC+Iron+Wood)', 'Alternative_Cement_MF'] = MS_data.loc['PC', 'Alternative_Cement_MF'] + MS_data.loc['Iron/Steel', 'Alternative_Cement_MF'] + MS_data.loc['Wood (Total)', 'Alternative_Cement_MF']
MS_data.loc['Total (PC+AC+Iron+Wood)', 'Alternative_Cement_MF'] =  MS_data.loc['PC', 'Alternative_Cement_MF'] + MS_data.loc['Iron/Steel', 'Alternative_Cement_MF'] + MS_data.loc['Wood (Total)', 'Alternative_Cement_MF'] + MS_data.loc['AC', 'Alternative_Cement_MF']


# + Alternative Cement MF

MS_data.loc['Concrete (w/ PC)', "'+ Alternative_Cement_MF"] = (FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_MRMF'] * MI_Con_LF + FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_HRMF'] * MI_Con_RC) + (FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_New_MRMF'] * MI_Con_LF+ FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_New_HRMF'] * MI_Con_RC) * (1 - SC_EU)
MS_data.loc['Iron/Steel', "'+ Alternative_Cement_MF"] = (FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_MRMF'] + FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_New_MRMF'] + FA_data.loc["'+ Alternative Cement", 'AC_Total_FA_MRMF']) * MI_Iron_LF + (FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_HRMF'] + FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_New_HRMF'] + FA_data.loc["'+ Alternative Cement", 'AC_Total_FA_HRMF']) * MI_Iron_RC
MS_data.loc['Wood (Total)', "'+ Alternative_Cement_MF"] =  (FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_MRMF'] + FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_New_MRMF'] + FA_data.loc["'+ Alternative Cement", 'AC_Total_FA_MRMF']) * MI_Wood_LF + (FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_HRMF'] + FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_New_HRMF'] + FA_data.loc["'+ Alternative Cement", 'AC_Total_FA_HRMF']) * MI_Wood_RC
MS_data.loc['Wood (except CLT)', "'+ Alternative_Cement_MF"] =  (FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_MRMF'] + FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_New_MRMF'] + FA_data.loc["'+ Alternative Cement", 'AC_Total_FA_MRMF']) * MI_Wood_no_CLT_LF + (FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_HRMF'] + FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_New_HRMF'] + FA_data.loc["'+ Alternative Cement", 'AC_Total_FA_HRMF']) * MI_Wood_no_CLT_RC
MS_data.loc['CLT', "'+ Alternative_Cement_MF"] =  (FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_MRMF'] + FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_New_MRMF'] + FA_data.loc["'+ Alternative Cement", 'AC_Total_FA_MRMF']) * MI_CLT_LF+ (FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_HRMF'] + FA_data.loc["'+ Alternative Cement", 'Conv_Total_FA_New_HRMF'] + FA_data.loc["'+ Alternative Cement", 'AC_Total_FA_HRMF']) * MI_CLT_RC
MS_data.loc['PC', "'+ Alternative_Cement_MF"] = MS_data.loc['Concrete (w/ PC)', "'+ Alternative_Cement_MF"] * Cement_Mix
MS_data.loc['Concrete (w/ AC)', "'+ Alternative_Cement_MF"] = (FA_data.loc["'+ Alternative Cement", 'AC_Total_FA_MRMF'] * MI_Con_LF + FA_data.loc["'+ Alternative Cement", 'AC_Total_FA_HRMF'] * MI_Con_RC) * (1 - SC_EU)
MS_data.loc['AC', "'+ Alternative_Cement_MF"] = MS_data.loc['Concrete (w/ AC)', "'+ Alternative_Cement_MF"] * Cement_Mix
MS_data.loc['Total (Concrete+Iron+Wood)', "'+ Alternative_Cement_MF"] = MS_data.loc['Concrete (w/ PC)', "'+ Alternative_Cement_MF"] + MS_data.loc['Iron/Steel', "'+ Alternative_Cement_MF"] + MS_data.loc['Wood (Total)', "'+ Alternative_Cement_MF"]
MS_data.loc['Total (PC+Iron+Wood)', "'+ Alternative_Cement_MF"] = MS_data.loc['PC', "'+ Alternative_Cement_MF"] + MS_data.loc['Iron/Steel', "'+ Alternative_Cement_MF"] + MS_data.loc['Wood (Total)', "'+ Alternative_Cement_MF"]
MS_data.loc['Total (PC+AC+Iron+Wood)', "'+ Alternative_Cement_MF"] =  MS_data.loc['PC', "'+ Alternative_Cement_MF"] + MS_data.loc['Iron/Steel', "'+ Alternative_Cement_MF"] + MS_data.loc['Wood (Total)', "'+ Alternative_Cement_MF"] + MS_data.loc['AC', "'+ Alternative_Cement_MF"]

MS_data
# Out:
#                               BAU2018_SF    BAU2018_MF  BAU2018_Total  \
# Concrete (w/ PC)            2.149525e+06  2.097309e+06              0
# Iron/Steel                  1.115043e+05  1.087956e+05              0
# Wood (Total)                7.119736e+05  6.946784e+05              0
# Wood (except CLT)           7.119736e+05  6.946784e+05              0
# CLT                         0.000000e+00  0.000000e+00              0
# PC                          2.708402e+05  2.642610e+05              0
# Concrete (w/ AC)            0.000000e+00  0.000000e+00              0
# AC                          0.000000e+00  0.000000e+00              0
# Total (Concrete+Iron+Wood)  2.973003e+06  2.900783e+06              0
# Total (PC+Iron+Wood)        1.094318e+06  1.067735e+06              0
# Total (PC+AC+Iron+Wood)     1.094318e+06  1.067735e+06              0
#
#                               BAU2020_SF    BAU2020_MF  BAU2020_Total  \
# ...

# %%
MI_Con_RC
# Out:
# 1.193859649

# %% [markdown]
# ### Total

# %%
# BAU 2018 Total
MS_data['BAU2020_Total'] = MS_data['BAU2020_SF'] + MS_data['BAU2020_MF']

# %%
# Make a loop for total
for scenario in ['BAU2018_Total', 'BAU2020_Total', 'BAU2040_Total', 'Compact_City_Total', 'Effective_Design_Total', 'Intensive_Use_Total', 'Mass_Timber_Total', 'Alternative_Cement_Total', "'+ Effective_Design_Total", "'+ Intensive_Use_Total", "'+ Mass_Timber_Total", "'+ Alternative_Cement_Total"]:
    if scenario == 'BAU2018_Total':
        SF_scenario = 'BAU2018_SF'
        MF_scenario = 'BAU2018_MF'
    elif scenario == 'BAU2020_Total':
        SF_scenario = 'BAU2020_SF'
        MF_scenario = 'BAU2020_MF'
    elif scenario == 'BAU2040_Total':
        SF_scenario = 'BAU2040_SF'
        MF_scenario = 'BAU2040_MF'
    elif scenario == 'BAU2040_Total':
        SF_scenario = 'BAU2040_SF'
        MF_scenario = 'BAU2040_MF'
    elif scenario == 'Compact_City_Total':
        SF_scenario = 'Compact_City_SF'
        MF_scenario = 'Compact_City_MF'
    elif scenario == 'Effective_Design_Total':
        SF_scenario = 'Effective_Design_SF'
        MF_scenario = 'Effective_Design_MF'    
    elif scenario == 'Intensive_Use_Total':
        SF_scenario = 'Intensive_Use_SF'
        MF_scenario = 'Intensive_Use_MF'  
    elif scenario == 'Mass_Timber_Total':
        SF_scenario = 'Mass_Timber_SF'
        MF_scenario = 'Mass_Timber_MF'  
    elif scenario == 'Alternative_Cement_Total':
        SF_scenario = 'Alternative_Cement_SF'
        MF_scenario = 'Alternative_Cement_MF'  
    elif scenario == "'+ Effective_Design_Total":
        SF_scenario = "'+ Effective_Design_SF"
        MF_scenario = "'+ Effective_Design_MF"  
    elif scenario == "'+ Intensive_Use_Total":
        SF_scenario = "'+ Intensive_Use_SF"
        MF_scenario = "'+ Intensive_Use_MF"  
    elif scenario == "'+ Mass_Timber_Total":
        SF_scenario = "'+ Mass_Timber_SF"
        MF_scenario = "'+ Mass_Timber_MF"  
    elif scenario == "'+ Alternative_Cement_Total":
        SF_scenario = "'+ Alternative_Cement_SF"
        MF_scenario = "'+ Alternative_Cement_MF"

    MS_data[scenario] = MS_data[SF_scenario] + MS_data[MF_scenario]

MS_data
# Out:
#                               BAU2018_SF    BAU2018_MF  BAU2018_Total  \
# Concrete (w/ PC)            2.149525e+06  2.097309e+06   4.246835e+06
# Iron/Steel                  1.115043e+05  1.087956e+05   2.202999e+05
# Wood (Total)                7.119736e+05  6.946784e+05   1.406652e+06
# Wood (except CLT)           7.119736e+05  6.946784e+05   1.406652e+06
# CLT                         0.000000e+00  0.000000e+00   0.000000e+00
# PC                          2.708402e+05  2.642610e+05   5.351012e+05
# Concrete (w/ AC)            0.000000e+00  0.000000e+00   0.000000e+00
# AC                          0.000000e+00  0.000000e+00   0.000000e+00
# Total (Concrete+Iron+Wood)  2.973003e+06  2.900783e+06   5.873787e+06
# Total (PC+Iron+Wood)        1.094318e+06  1.067735e+06   2.162053e+06
# Total (PC+AC+Iron+Wood)     1.094318e+06  1.067735e+06   2.162053e+06
#
#                               BAU2020_SF    BAU2020_MF  BAU2020_Total  \
# ...

# %%
MS_data.to_csv('/Users/akihi/Library/CloudStorage/OneDrive-PrincetonUniversity/Projects/Building Material in Cities/1st Research/Code/Separated Code/MFA/Material Stock.csv', index=True)

# %% [markdown]
# ## Material Inflow

# %%
# Prepare the dataframe
column = {'BAU2018_SF': [], 'BAU2018_MF': [], 'BAU2018_Total': [], \
      'BAU2020_SF': [], 'BAU2020_MF': [], 'BAU2020_Total': [], 'BAU2020_Annual': [], \
       'BAU2040_SF': [], 'BAU2040_MF': [], 'BAU2040_Total': [], 'BAU2040_Annual' : [], \
        'Compact_City_SF': [], 'Compact_City_MF': [], 'Compact_City_Total': [], 'Compact_City_Annual': [], \
         'Effective_Design_SF': [], 'Effective_Design_MF': [], 'Effective_Design_Total': [], 'Effective_Design_Annual': [], \
            'Intensive_Use_SF': [], 'Intensive_Use_MF': [], 'Intensive_Use_Total': [], 'Intensive_Use_Annual': [], \
             'Mass_Timber_SF': [], 'Mass_Timber_MF': [], 'Mass_Timber_Total': [], 'Mass_Timber_Annual': [], \
               'Alternative_Cement_SF': [], 'Alternative_Cement_MF': [], 'Alternative_Cement_Total': [], 'Alternative_Cement_Annual': [], \
                "'+ Effective_Design_SF": [], "'+ Effective_Design_MF": [], "'+ Effective_Design_Total": [], "'+ Effective_Design_Annual": [], \
                  "'+ Intensive_Use_SF": [], "'+ Intensive_Use_MF": [], "'+ Intensive_Use_Total": [], "'+ Intensive_Use_Annual": [], \
                    "'+ Mass_Timber_SF": [], "'+ Mass_Timber_MF": [], "'+ Mass_Timber_Total": [], "'+ Mass_Timber_Annual": [], \
                      "'+ Alternative_Cement_SF": [], "'+ Alternative_Cement_MF": [], "'+ Alternative_Cement_Total": [], "'+ Alternative_Cement_Total": []}
index = ['Concrete (w/ PC)', 'Iron/Steel', 'Wood (Total)', 'Wood (except CLT)', 'CLT', 'PC', 'Concrete (w/ AC)', 'AC',
         'Total (Concrete+Iron+Wood)', 'Total (PC+Iron+Wood)', 'Total (PC+AC+Iron+Wood)']


MI_data = pd.DataFrame(index=index, columns=column.keys())
MI_data = MI_data.fillna(0)

# %%
MI_data = MI_data.drop(MI_data.columns[[0, 1, 2]], axis=1)
MI_data
# Out:
#                             BAU2020_SF  BAU2020_MF  BAU2020_Total  \
# Concrete (w/ PC)                     0           0              0
# Iron/Steel                           0           0              0
# Wood (Total)                         0           0              0
# Wood (except CLT)                    0           0              0
# CLT                                  0           0              0
# PC                                   0           0              0
# Concrete (w/ AC)                     0           0              0
# AC                                   0           0              0
# Total (Concrete+Iron+Wood)           0           0              0
# Total (PC+Iron+Wood)                 0           0              0
# Total (PC+AC+Iron+Wood)              0           0              0
#
#                             BAU2020_Annual  BAU2040_SF  BAU2040_MF  \
# Concrete (w/ PC)                         0           0           0
# ...

# %%
# Make a loop for SF
for scenario in ['BAU2020_SF', 'BAU2040_SF', 'Compact_City_SF', 'Effective_Design_SF', 'Intensive_Use_SF', 'Mass_Timber_SF', 'Alternative_Cement_SF', "'+ Effective_Design_SF", "'+ Intensive_Use_SF", "'+ Mass_Timber_SF", "'+ Alternative_Cement_SF"]:
    MI_data[scenario] = MS_data[scenario] - MS_data['BAU2018_SF']

# Make a loop for MF
for scenario in ['BAU2020_MF', 'BAU2040_MF', 'Compact_City_MF', 'Effective_Design_MF', 'Intensive_Use_MF', 'Mass_Timber_MF', 'Alternative_Cement_MF', "'+ Effective_Design_MF", "'+ Intensive_Use_MF", "'+ Mass_Timber_MF", "'+ Alternative_Cement_MF"]:
    MI_data[scenario] = MS_data[scenario] - MS_data['BAU2018_MF']

# Make a loop for MI Total
for scenario in ['BAU2020_Total', 'BAU2040_Total', 'Compact_City_Total', 'Effective_Design_Total', 'Intensive_Use_Total', 'Mass_Timber_Total', 'Alternative_Cement_Total', "'+ Effective_Design_Total", "'+ Intensive_Use_Total", "'+ Mass_Timber_Total", "'+ Alternative_Cement_Total"]:
    if scenario == 'BAU2018_Total':
        SF_scenario = 'BAU2018_SF'
        MF_scenario = 'BAU2018_MF'
    elif scenario == 'BAU2020_Total':
        SF_scenario = 'BAU2020_SF'
        MF_scenario = 'BAU2020_MF'
    elif scenario == 'BAU2040_Total':
        SF_scenario = 'BAU2040_SF'
        MF_scenario = 'BAU2040_MF'
    elif scenario == 'BAU2040_Total':
        SF_scenario = 'BAU2040_SF'
        MF_scenario = 'BAU2040_MF'
    elif scenario == 'Compact_City_Total':
        SF_scenario = 'Compact_City_SF'
        MF_scenario = 'Compact_City_MF'
    elif scenario == 'Effective_Design_Total':
        SF_scenario = 'Effective_Design_SF'
        MF_scenario = 'Effective_Design_MF'    
    elif scenario == 'Intensive_Use_Total':
        SF_scenario = 'Intensive_Use_SF'
        MF_scenario = 'Intensive_Use_MF'  
    elif scenario == 'Mass_Timber_Total':
        SF_scenario = 'Mass_Timber_SF'
        MF_scenario = 'Mass_Timber_MF'  
    elif scenario == 'Alternative_Cement_Total':
        SF_scenario = 'Alternative_Cement_SF'
        MF_scenario = 'Alternative_Cement_MF'  
    elif scenario == "'+ Effective_Design_Total":
        SF_scenario = "'+ Effective_Design_SF"
        MF_scenario = "'+ Effective_Design_MF"  
    elif scenario == "'+ Intensive_Use_Total":
        SF_scenario = "'+ Intensive_Use_SF"
        MF_scenario = "'+ Intensive_Use_MF"  
    elif scenario == "'+ Mass_Timber_Total":
        SF_scenario = "'+ Mass_Timber_SF"
        MF_scenario = "'+ Mass_Timber_MF"  
    elif scenario == "'+ Alternative_Cement_Total":
        SF_scenario = "'+ Alternative_Cement_SF"
        MF_scenario = "'+ Alternative_Cement_MF"

    MI_data[scenario] = MI_data[SF_scenario] + MI_data[MF_scenario]

# Make a loop for Annual MI
MI_data['BAU2020_Annual'] = MI_data['BAU2020_Total'] / 2

for scenario in ['BAU2040_Annual', 'Compact_City_Annual', 'Effective_Design_Annual', 'Intensive_Use_Annual', 'Mass_Timber_Annual', 'Alternative_Cement_Annual', "'+ Effective_Design_Annual", "'+ Intensive_Use_Annual", "'+ Mass_Timber_Annual", "'+ Alternative_Cement_Annual"]:
    if scenario == 'BAU2040_Annual':
        base_scenario = 'BAU2040_Total'
    elif scenario == 'Compact_City_Annual':
        base_scenario= 'Compact_City_Total'
    elif scenario == 'Effective_Design_Annual':
        base_scenario= 'Effective_Design_Total'
    elif scenario == 'Intensive_Use_Annual':
        base_scenario= 'Intensive_Use_Total'
    elif scenario == 'Mass_Timber_Annual':
        base_scenario= 'Mass_Timber_Total'
    elif scenario == 'Alternative_Cement_Annual':
        base_scenario= 'Alternative_Cement_Total'
    elif scenario == "'+ Effective_Design_Annual":
        base_scenario= "'+ Effective_Design_Total"
    elif scenario == "'+ Intensive_Use_Annual":
        base_scenario= "'+ Intensive_Use_Total"
    elif scenario == "'+ Mass_Timber_Annual":
        base_scenario= "'+ Mass_Timber_Total"
    elif scenario == "'+ Alternative_Cement_Annual":
        base_scenario= "'+ Alternative_Cement_Total"

    MI_data[scenario] = MI_data[base_scenario] / 22

MI_data
# Out:
#                              BAU2020_SF    BAU2020_MF  BAU2020_Total  \
# Concrete (w/ PC)            2826.061046  40870.259922   43696.320969
# Iron/Steel                   146.598851   2120.100395    2266.699246
# Wood (Total)                 936.058194  13537.195788   14473.253982
# Wood (except CLT)            936.058194  13537.195788   14473.253982
# CLT                            0.000000      0.000000       0.000000
# PC                           356.083692   5149.652750    5505.736442
# Concrete (w/ AC)               0.000000      0.000000       0.000000
# AC                             0.000000      0.000000       0.000000
# Total (Concrete+Iron+Wood)  3908.718091  56527.556105   60436.274197
# Total (PC+Iron+Wood)        1438.740737  20806.948933   22245.689670
# Total (PC+AC+Iron+Wood)     1438.740737  20806.948933   22245.689670
#
#                             BAU2020_Annual    BAU2040_SF     BAU2040_MF  \
# ...

# %%
MI_data.to_csv('/Users/akihi/Library/CloudStorage/OneDrive-PrincetonUniversity/Projects/Building Material in Cities/1st Research/Code/Separated Code/MFA/Material Inflow.csv', index=True)

# %% [markdown]
# ## Material Outflow

# %%
# Prepare the dataframe
MO_data = pd.DataFrame(index=index, columns=column.keys())
MO_data = MO_data.fillna(0)

MO_data = MO_data.drop(MO_data.columns[[0, 1, 2]], axis=1)
MO_data
# Out:
#                             BAU2020_SF  BAU2020_MF  BAU2020_Total  \
# Concrete (w/ PC)                     0           0              0
# Iron/Steel                           0           0              0
# Wood (Total)                         0           0              0
# Wood (except CLT)                    0           0              0
# CLT                                  0           0              0
# PC                                   0           0              0
# Concrete (w/ AC)                     0           0              0
# AC                                   0           0              0
# Total (Concrete+Iron+Wood)           0           0              0
# Total (PC+Iron+Wood)                 0           0              0
# Total (PC+AC+Iron+Wood)              0           0              0
#
#                             BAU2020_Annual  BAU2040_SF  BAU2040_MF  \
# Concrete (w/ PC)                         0           0           0
# ...

# %%
# Make a loop for SF

for scenario in ['BAU2020_SF', 'BAU2040_SF', 'Compact_City_SF', 'Effective_Design_SF', 'Intensive_Use_SF', 'Mass_Timber_SF', 'Alternative_Cement_SF', "'+ Effective_Design_SF", "'+ Intensive_Use_SF", "'+ Mass_Timber_SF", "'+ Alternative_Cement_SF"]:
    if scenario == 'BAU2020_SF':
        base_scenario = 'BAU 2020'
    elif scenario == 'BAU2040_SF':
        base_scenario = 'BAU 2040'
    elif scenario == 'Compact_City_SF':
        base_scenario= 'Compact City'
    elif scenario == 'Effective_Design_SF':
        base_scenario= 'Effective Design'
    elif scenario == 'Intensive_Use_SF':
        base_scenario= 'Intensive Use'
    elif scenario == 'Mass_Timber_SF':
        base_scenario= 'Mass-Timber'
    elif scenario == 'Alternative_Cement_SF':
        base_scenario= 'Alternative Cement'
    elif scenario == "'+ Effective_Design_SF":
        base_scenario= "'+ Effective Use"
    elif scenario == "'+ Intensive_Use_SF":
        base_scenario= "'+ Intensive Use"
    elif scenario == "'+ Mass_Timber_SF":
        base_scenario= "'+ Mass-Timber"
    elif scenario == "'+ Alternative_Cement_SF":
        base_scenario= "'+ Alternative Cement"


    MO_data.loc['Concrete (w/ PC)', scenario] = FA_data.loc[base_scenario, 'Total_FA_Dem_LFSF'] * MI_Con_LF + FA_data.loc[base_scenario, 'Conv_Total_FA_New_LFSF'] * MI_Waste_Con_LF + FA_data.loc[base_scenario, 'Total_FA_Dem_RCSF'] * MI_Con_RC
    MO_data.loc['Iron/Steel', scenario] = FA_data.loc[base_scenario, 'Total_FA_Dem_LFSF'] * MI_Iron_LF + FA_data.loc[base_scenario, 'Conv_Total_FA_New_LFSF'] * MI_Waste_Iron_LF + FA_data.loc[base_scenario, 'Total_FA_Dem_RCSF'] * MI_Iron_RC
    MO_data.loc['Wood (Total)', scenario] = FA_data.loc[base_scenario, 'Total_FA_Dem_LFSF'] * MI_Wood_LF + FA_data.loc[base_scenario, 'Conv_Total_FA_New_LFSF'] * MI_Waste_Wood_LF + FA_data.loc[base_scenario, 'Total_FA_Dem_RCSF'] * MI_Wood_RC
    MO_data.loc['PC', scenario] = MO_data.loc['Concrete (w/ PC)', scenario] * Cement_Mix

    MO_data.loc['Total (Concrete+Iron+Wood)', scenario] = MO_data.loc['Concrete (w/ PC)', scenario] + MO_data.loc['Iron/Steel', scenario] + MO_data.loc['Wood (Total)', scenario]
    MO_data.loc['Total (PC+Iron+Wood)', scenario] = MO_data.loc['PC', scenario] + MO_data.loc['Iron/Steel', scenario] + MO_data.loc['Wood (Total)', scenario]
    MO_data.loc['Total (PC+AC+Iron+Wood)', scenario] =  MO_data.loc['PC', scenario] + MO_data.loc['Iron/Steel', scenario] + MO_data.loc['Wood (Total)', scenario] + MO_data.loc['AC', scenario]


MO_data
# Out:
#                              BAU2020_SF  BAU2020_MF  BAU2020_Total  \
# Concrete (w/ PC)            1805.199176           0              0
# Iron/Steel                    96.277448           0              0
# Wood (Total)                 707.481652           0              0
# Wood (except CLT)              0.000000           0              0
# CLT                            0.000000           0              0
# PC                           227.455096           0              0
# Concrete (w/ AC)               0.000000           0              0
# AC                             0.000000           0              0
# Total (Concrete+Iron+Wood)  2608.958276           0              0
# Total (PC+Iron+Wood)        1031.214196           0              0
# Total (PC+AC+Iron+Wood)     1031.214196           0              0
#
#                             BAU2020_Annual    BAU2040_SF  BAU2040_MF  \
# Concrete (w/ PC)                         0  19857.190660           0
# ...

# %%
# Make a loop for MF

for scenario in ['BAU2020_MF', 'BAU2040_MF', 'Compact_City_MF', 'Effective_Design_MF', 'Intensive_Use_MF', 'Mass_Timber_MF', 'Alternative_Cement_MF', "'+ Effective_Design_MF", "'+ Intensive_Use_MF", "'+ Mass_Timber_MF", "'+ Alternative_Cement_MF"]:
    if scenario == 'BAU2020_MF':
        base_scenario = 'BAU 2020'
    elif scenario == 'BAU2040_MF':
        base_scenario = 'BAU 2040'
    elif scenario == 'Compact_City_MF':
        base_scenario= 'Compact City'
    elif scenario == 'Effective_Design_MF':
        base_scenario= 'Effective Design'
    elif scenario == 'Intensive_Use_MF':
        base_scenario= 'Intensive Use'
    elif scenario == 'Mass_Timber_MF':
        base_scenario= 'Mass-Timber'
    elif scenario == 'Alternative_Cement_MF':
        base_scenario= 'Alternative Cement'
    elif scenario == "'+ Effective_Design_MF":
        base_scenario= "'+ Effective Use"
    elif scenario == "'+ Intensive_Use_MF":
        base_scenario= "'+ Intensive Use"
    elif scenario == "'+ Mass_Timber_MF":
        base_scenario= "'+ Mass-Timber"
    elif scenario == "'+ Alternative_Cement_MF":
        base_scenario= "'+ Alternative Cement"

    MO_data.loc['Concrete (w/ PC)', scenario] = FA_data.loc[base_scenario, 'Total_FA_Dem_MRMF'] * MI_Con_LF + FA_data.loc[base_scenario, 'Total_FA_Dem_HRMF'] * MI_Con_RC + FA_data.loc[base_scenario, 'Conv_Total_FA_New_MRMF'] * MI_Waste_Con_LF + FA_data.loc[base_scenario, 'Conv_Total_FA_New_HRMF'] * MI_Waste_Con_RC
    MO_data.loc['Iron/Steel', scenario] = FA_data.loc[base_scenario, 'Total_FA_Dem_MRMF'] * MI_Iron_LF + FA_data.loc[base_scenario, 'Total_FA_Dem_HRMF'] * MI_Iron_RC + FA_data.loc[base_scenario, 'Conv_Total_FA_New_MRMF'] * MI_Waste_Iron_LF + FA_data.loc[base_scenario, 'Conv_Total_FA_New_HRMF'] * MI_Waste_Iron_RC    
    MO_data.loc['Wood (Total)', scenario] = FA_data.loc[base_scenario, 'Total_FA_Dem_MRMF'] * MI_Wood_LF + FA_data.loc[base_scenario, 'Total_FA_Dem_HRMF'] * MI_Wood_RC + FA_data.loc[base_scenario, 'Conv_Total_FA_New_MRMF'] * MI_Waste_Wood_LF + FA_data.loc[base_scenario, 'Conv_Total_FA_New_HRMF'] * MI_Waste_Wood_RC
    MO_data.loc['PC', scenario] = MO_data.loc['Concrete (w/ PC)', scenario] * Cement_Mix

    MO_data.loc['Total (Concrete+Iron+Wood)', scenario] = MO_data.loc['Concrete (w/ PC)', scenario] + MO_data.loc['Iron/Steel', scenario] + MO_data.loc['Wood (Total)', scenario]
    MO_data.loc['Total (PC+Iron+Wood)', scenario] = MO_data.loc['PC', scenario] + MO_data.loc['Iron/Steel', scenario] + MO_data.loc['Wood (Total)', scenario]
    MO_data.loc['Total (PC+AC+Iron+Wood)', scenario] =  MO_data.loc['PC', scenario] + MO_data.loc['Iron/Steel', scenario] + MO_data.loc['Wood (Total)', scenario] + MO_data.loc['AC', scenario]


MO_data
# Out:
#                              BAU2020_SF   BAU2020_MF  BAU2020_Total  \
# Concrete (w/ PC)            1805.199176  2689.165836              0
# Iron/Steel                    96.277448   174.270880              0
# Wood (Total)                 707.481652  2461.416131              0
# Wood (except CLT)              0.000000     0.000000              0
# CLT                            0.000000     0.000000              0
# PC                           227.455096   338.834895              0
# Concrete (w/ AC)               0.000000     0.000000              0
# AC                             0.000000     0.000000              0
# Total (Concrete+Iron+Wood)  2608.958276  5324.852847              0
# Total (PC+Iron+Wood)        1031.214196  2974.521906              0
# Total (PC+AC+Iron+Wood)     1031.214196  2974.521906              0
#
#                             BAU2020_Annual    BAU2040_SF    BAU2040_MF  \
# Concrete (w/ PC)                         0  19857.190660  29530.895834
# ...

# %%
# Make a loop for MO Total
for scenario in ['BAU2020_Total', 'BAU2040_Total', 'Compact_City_Total', 'Effective_Design_Total', 'Intensive_Use_Total', 'Mass_Timber_Total', 'Alternative_Cement_Total', "'+ Effective_Design_Total", "'+ Intensive_Use_Total", "'+ Mass_Timber_Total", "'+ Alternative_Cement_Total"]:
    if scenario == 'BAU2018_Total':
        SF_scenario = 'BAU2018_SF'
        MF_scenario = 'BAU2018_MF'
    elif scenario == 'BAU2020_Total':
        SF_scenario = 'BAU2020_SF'
        MF_scenario = 'BAU2020_MF'
    elif scenario == 'BAU2040_Total':
        SF_scenario = 'BAU2040_SF'
        MF_scenario = 'BAU2040_MF'
    elif scenario == 'BAU2040_Total':
        SF_scenario = 'BAU2040_SF'
        MF_scenario = 'BAU2040_MF'
    elif scenario == 'Compact_City_Total':
        SF_scenario = 'Compact_City_SF'
        MF_scenario = 'Compact_City_MF'
    elif scenario == 'Effective_Design_Total':
        SF_scenario = 'Effective_Design_SF'
        MF_scenario = 'Effective_Design_MF'    
    elif scenario == 'Intensive_Use_Total':
        SF_scenario = 'Intensive_Use_SF'
        MF_scenario = 'Intensive_Use_MF'  
    elif scenario == 'Mass_Timber_Total':
        SF_scenario = 'Mass_Timber_SF'
        MF_scenario = 'Mass_Timber_MF'  
    elif scenario == 'Alternative_Cement_Total':
        SF_scenario = 'Alternative_Cement_SF'
        MF_scenario = 'Alternative_Cement_MF'  
    elif scenario == "'+ Effective_Design_Total":
        SF_scenario = "'+ Effective_Design_SF"
        MF_scenario = "'+ Effective_Design_MF"  
    elif scenario == "'+ Intensive_Use_Total":
        SF_scenario = "'+ Intensive_Use_SF"
        MF_scenario = "'+ Intensive_Use_MF"  
    elif scenario == "'+ Mass_Timber_Total":
        SF_scenario = "'+ Mass_Timber_SF"
        MF_scenario = "'+ Mass_Timber_MF"  
    elif scenario == "'+ Alternative_Cement_Total":
        SF_scenario = "'+ Alternative_Cement_SF"
        MF_scenario = "'+ Alternative_Cement_MF"

    MO_data[scenario] = MO_data[SF_scenario] + MO_data[MF_scenario]

# Make a loop for Annual MO
MO_data['BAU2020_Annual'] = MO_data['BAU2020_Total'] / 2

for scenario in ['BAU2040_Annual', 'Compact_City_Annual', 'Effective_Design_Annual', 'Intensive_Use_Annual', 'Mass_Timber_Annual', 'Alternative_Cement_Annual', "'+ Effective_Design_Annual", "'+ Intensive_Use_Annual", "'+ Mass_Timber_Annual", "'+ Alternative_Cement_Annual"]:
    if scenario == 'BAU2040_Annual':
        base_scenario = 'BAU2040_Total'
    elif scenario == 'Compact_City_Annual':
        base_scenario= 'Compact_City_Total'
    elif scenario == 'Effective_Design_Annual':
        base_scenario= 'Effective_Design_Total'
    elif scenario == 'Intensive_Use_Annual':
        base_scenario= 'Intensive_Use_Total'
    elif scenario == 'Mass_Timber_Annual':
        base_scenario= 'Mass_Timber_Total'
    elif scenario == 'Alternative_Cement_Annual':
        base_scenario= 'Alternative_Cement_Total'
    elif scenario == "'+ Effective_Design_Annual":
        base_scenario= "'+ Effective_Design_Total"
    elif scenario == "'+ Intensive_Use_Annual":
        base_scenario= "'+ Intensive_Use_Total"
    elif scenario == "'+ Mass_Timber_Annual":
        base_scenario= "'+ Mass_Timber_Total"
    elif scenario == "'+ Alternative_Cement_Annual":
        base_scenario= "'+ Alternative_Cement_Total"

    MO_data[scenario] = MO_data[base_scenario] / 22

MO_data
# Out:
#                              BAU2020_SF   BAU2020_MF  BAU2020_Total  \
# Concrete (w/ PC)            1805.199176  2689.165836    4494.365012
# Iron/Steel                    96.277448   174.270880     270.548327
# Wood (Total)                 707.481652  2461.416131    3168.897783
# Wood (except CLT)              0.000000     0.000000       0.000000
# CLT                            0.000000     0.000000       0.000000
# PC                           227.455096   338.834895     566.289991
# Concrete (w/ AC)               0.000000     0.000000       0.000000
# AC                             0.000000     0.000000       0.000000
# Total (Concrete+Iron+Wood)  2608.958276  5324.852847    7933.811122
# Total (PC+Iron+Wood)        1031.214196  2974.521906    4005.736102
# Total (PC+AC+Iron+Wood)     1031.214196  2974.521906    4005.736102
#
#                             BAU2020_Annual    BAU2040_SF    BAU2040_MF  \
# Concrete (w/ PC)               2247.182506  19857.190660  29530.895834
# ...

# %%
MO_data.to_csv('/Users/akihi/Library/CloudStorage/OneDrive-PrincetonUniversity/Projects/Building Material in Cities/1st Research/Code/Separated Code/MFA/Material Outflow.csv', index=True)

# %% [markdown]
# ## Landfill

# %%
# Prepare the dataframe
Land_data = pd.DataFrame(index=index, columns=column.keys())
Land_data = Land_data.fillna(0)

Land_data = Land_data.drop(Land_data.columns[[0, 1, 2]], axis=1)
Land_data
# Out:
#                             BAU2020_SF  BAU2020_MF  BAU2020_Total  \
# Concrete (w/ PC)                     0           0              0
# Iron/Steel                           0           0              0
# Wood (Total)                         0           0              0
# Wood (except CLT)                    0           0              0
# CLT                                  0           0              0
# PC                                   0           0              0
# Concrete (w/ AC)                     0           0              0
# AC                                   0           0              0
# Total (Concrete+Iron+Wood)           0           0              0
# Total (PC+Iron+Wood)                 0           0              0
# Total (PC+AC+Iron+Wood)              0           0              0
#
#                             BAU2020_Annual  BAU2040_SF  BAU2040_MF  \
# Concrete (w/ PC)                         0           0           0
# ...

# %%
# Make a loop for Landfill SF
for scenario in ['BAU2020_SF', 'BAU2040_SF', 'Compact_City_SF', 'Effective_Design_SF', 'Intensive_Use_SF', 'Mass_Timber_SF', 'Alternative_Cement_SF', "'+ Effective_Design_SF", "'+ Intensive_Use_SF", "'+ Mass_Timber_SF", "'+ Alternative_Cement_SF"]:
    Land_data.loc['Concrete (w/ PC)', scenario] = MO_data.loc['Concrete (w/ PC)', scenario] * (1 - NU_Con)
    Land_data.loc['Iron/Steel', scenario] = MO_data.loc['Iron/Steel', scenario] * (1 - NU_Iron)
    Land_data.loc['Wood (Total)', scenario] = MO_data.loc['Wood (Total)', scenario] * (1 - NU_Wood)
    Land_data.loc['PC', scenario] = Land_data.loc['Concrete (w/ PC)', scenario] * Cement_Mix

    Land_data.loc['Total (Concrete+Iron+Wood)', scenario] = Land_data.loc['Concrete (w/ PC)', scenario] + Land_data.loc['Iron/Steel', scenario] + Land_data.loc['Wood (Total)', scenario]
    Land_data.loc['Total (PC+Iron+Wood)', scenario] = Land_data.loc['PC', scenario] + Land_data.loc['Iron/Steel', scenario] + Land_data.loc['Wood (Total)', scenario]
    Land_data.loc['Total (PC+AC+Iron+Wood)', scenario] =  Land_data.loc['PC', scenario] + Land_data.loc['Iron/Steel', scenario] + Land_data.loc['Wood (Total)', scenario] + Land_data.loc['AC', scenario]

# %%
# Make a loop for Landfill MF
for scenario in ['BAU2020_MF', 'BAU2040_MF', 'Compact_City_MF', 'Effective_Design_MF', 'Intensive_Use_MF', 'Mass_Timber_MF', 'Alternative_Cement_MF', "'+ Effective_Design_MF", "'+ Intensive_Use_MF", "'+ Mass_Timber_MF", "'+ Alternative_Cement_MF"]:
    Land_data.loc['Concrete (w/ PC)', scenario] = MO_data.loc['Concrete (w/ PC)', scenario] * (1 - NU_Con)
    Land_data.loc['Iron/Steel', scenario] = MO_data.loc['Iron/Steel', scenario] * (1 - NU_Iron)
    Land_data.loc['Wood (Total)', scenario] = MO_data.loc['Wood (Total)', scenario] * (1 - NU_Wood)
    Land_data.loc['PC', scenario] = Land_data.loc['Concrete (w/ PC)', scenario] * Cement_Mix

    Land_data.loc['Total (Concrete+Iron+Wood)', scenario] = Land_data.loc['Concrete (w/ PC)', scenario] + Land_data.loc['Iron/Steel', scenario] + Land_data.loc['Wood (Total)', scenario]
    Land_data.loc['Total (PC+Iron+Wood)', scenario] = Land_data.loc['PC', scenario] + Land_data.loc['Iron/Steel', scenario] + Land_data.loc['Wood (Total)', scenario]
    Land_data.loc['Total (PC+AC+Iron+Wood)', scenario] =  Land_data.loc['PC', scenario] + Land_data.loc['Iron/Steel', scenario] + Land_data.loc['Wood (Total)', scenario] + Land_data.loc['AC', scenario]

# %%
# Make a loop for Landfill Total
for scenario in ['BAU2020_Total', 'BAU2040_Total', 'Compact_City_Total', 'Effective_Design_Total', 'Intensive_Use_Total', 'Mass_Timber_Total', 'Alternative_Cement_Total', "'+ Effective_Design_Total", "'+ Intensive_Use_Total", "'+ Mass_Timber_Total", "'+ Alternative_Cement_Total"]:
    if scenario == 'BAU2018_Total':
        SF_scenario = 'BAU2018_SF'
        MF_scenario = 'BAU2018_MF'
    elif scenario == 'BAU2020_Total':
        SF_scenario = 'BAU2020_SF'
        MF_scenario = 'BAU2020_MF'
    elif scenario == 'BAU2040_Total':
        SF_scenario = 'BAU2040_SF'
        MF_scenario = 'BAU2040_MF'
    elif scenario == 'BAU2040_Total':
        SF_scenario = 'BAU2040_SF'
        MF_scenario = 'BAU2040_MF'
    elif scenario == 'Compact_City_Total':
        SF_scenario = 'Compact_City_SF'
        MF_scenario = 'Compact_City_MF'
    elif scenario == 'Effective_Design_Total':
        SF_scenario = 'Effective_Design_SF'
        MF_scenario = 'Effective_Design_MF'    
    elif scenario == 'Intensive_Use_Total':
        SF_scenario = 'Intensive_Use_SF'
        MF_scenario = 'Intensive_Use_MF'  
    elif scenario == 'Mass_Timber_Total':
        SF_scenario = 'Mass_Timber_SF'
        MF_scenario = 'Mass_Timber_MF'  
    elif scenario == 'Alternative_Cement_Total':
        SF_scenario = 'Alternative_Cement_SF'
        MF_scenario = 'Alternative_Cement_MF'  
    elif scenario == "'+ Effective_Design_Total":
        SF_scenario = "'+ Effective_Design_SF"
        MF_scenario = "'+ Effective_Design_MF"  
    elif scenario == "'+ Intensive_Use_Total":
        SF_scenario = "'+ Intensive_Use_SF"
        MF_scenario = "'+ Intensive_Use_MF"  
    elif scenario == "'+ Mass_Timber_Total":
        SF_scenario = "'+ Mass_Timber_SF"
        MF_scenario = "'+ Mass_Timber_MF"  
    elif scenario == "'+ Alternative_Cement_Total":
        SF_scenario = "'+ Alternative_Cement_SF"
        MF_scenario = "'+ Alternative_Cement_MF"

    Land_data[scenario] = Land_data[SF_scenario] + Land_data[MF_scenario]

# Make a loop for Annual Landfill
Land_data['BAU2020_Annual'] = Land_data['BAU2020_Total'] / 2

for scenario in ['BAU2040_Annual', 'Compact_City_Annual', 'Effective_Design_Annual', 'Intensive_Use_Annual', 'Mass_Timber_Annual', 'Alternative_Cement_Annual', "'+ Effective_Design_Annual", "'+ Intensive_Use_Annual", "'+ Mass_Timber_Annual", "'+ Alternative_Cement_Annual"]:
    if scenario == 'BAU2040_Annual':
        base_scenario = 'BAU2040_Total'
    elif scenario == 'Compact_City_Annual':
        base_scenario= 'Compact_City_Total'
    elif scenario == 'Effective_Design_Annual':
        base_scenario= 'Effective_Design_Total'
    elif scenario == 'Intensive_Use_Annual':
        base_scenario= 'Intensive_Use_Total'
    elif scenario == 'Mass_Timber_Annual':
        base_scenario= 'Mass_Timber_Total'
    elif scenario == 'Alternative_Cement_Annual':
        base_scenario= 'Alternative_Cement_Total'
    elif scenario == "'+ Effective_Design_Annual":
        base_scenario= "'+ Effective_Design_Total"
    elif scenario == "'+ Intensive_Use_Annual":
        base_scenario= "'+ Intensive_Use_Total"
    elif scenario == "'+ Mass_Timber_Annual":
        base_scenario= "'+ Mass_Timber_Total"
    elif scenario == "'+ Alternative_Cement_Annual":
        base_scenario= "'+ Alternative_Cement_Total"

    Land_data[scenario] = Land_data[base_scenario] / 22

Land_data
# Out:
#                             BAU2020_SF   BAU2020_MF  BAU2020_Total  \
# Concrete (w/ PC)            324.935852   484.049850     808.985702
# Iron/Steel                   17.329941    31.368758      48.698699
# Wood (Total)                516.461606  1796.833776    2313.295382
# Wood (except CLT)             0.000000     0.000000       0.000000
# CLT                           0.000000     0.000000       0.000000
# PC                           40.941917    60.990281     101.932198
# Concrete (w/ AC)              0.000000     0.000000       0.000000
# AC                            0.000000     0.000000       0.000000
# Total (Concrete+Iron+Wood)  858.727398  2312.252385    3170.979783
# Total (PC+Iron+Wood)        574.733464  1889.192815    2463.926279
# Total (PC+AC+Iron+Wood)     574.733464  1889.192815    2463.926279
#
#                             BAU2020_Annual   BAU2040_SF    BAU2040_MF  \
# Concrete (w/ PC)                404.492851  3574.294319   5315.561250
# ...

# %%
Land_data.to_csv('/Users/akihi/Library/CloudStorage/OneDrive-PrincetonUniversity/Projects/Building Material in Cities/1st Research/Code/Separated Code/MFA/Landfill.csv', index=True)

# %% [markdown]
# ## Next Use

# %%
# Prepare the dataframe
Next_Use_data = pd.DataFrame(index=index, columns=column.keys())
Next_Use_data = Next_Use_data.fillna(0)

Next_Use_data = Next_Use_data.drop(Next_Use_data.columns[[0, 1, 2]], axis=1)

# %%
# Make a loop for Next Use SF
for scenario in ['BAU2020_SF', 'BAU2040_SF', 'Compact_City_SF', 'Effective_Design_SF', 'Intensive_Use_SF', 'Mass_Timber_SF', 'Alternative_Cement_SF', "'+ Effective_Design_SF", "'+ Intensive_Use_SF", "'+ Mass_Timber_SF", "'+ Alternative_Cement_SF"]:
    Next_Use_data.loc['Concrete (w/ PC)', scenario] = MO_data.loc['Concrete (w/ PC)', scenario] * NU_Con
    Next_Use_data.loc['Iron/Steel', scenario] = MO_data.loc['Iron/Steel', scenario] * NU_Iron
    Next_Use_data.loc['Wood (Total)', scenario] = MO_data.loc['Wood (Total)', scenario] * NU_Wood
    Next_Use_data.loc['PC', scenario] = Next_Use_data.loc['Concrete (w/ PC)', scenario] * Cement_Mix

    Next_Use_data.loc['Total (Concrete+Iron+Wood)', scenario] = Next_Use_data.loc['Concrete (w/ PC)', scenario] + Next_Use_data.loc['Iron/Steel', scenario] + Next_Use_data.loc['Wood (Total)', scenario]
    Next_Use_data.loc['Total (PC+Iron+Wood)', scenario] = Next_Use_data.loc['PC', scenario] + Next_Use_data.loc['Iron/Steel', scenario] + Next_Use_data.loc['Wood (Total)', scenario]
    Next_Use_data.loc['Total (PC+AC+Iron+Wood)', scenario] =  Next_Use_data.loc['PC', scenario] + Next_Use_data.loc['Iron/Steel', scenario] + Next_Use_data.loc['Wood (Total)', scenario] + Next_Use_data.loc['AC', scenario]

# %%
# Make a loop for Next Use MF
for scenario in ['BAU2020_MF', 'BAU2040_MF', 'Compact_City_MF', 'Effective_Design_MF', 'Intensive_Use_MF', 'Mass_Timber_MF', 'Alternative_Cement_MF', "'+ Effective_Design_MF", "'+ Intensive_Use_MF", "'+ Mass_Timber_MF", "'+ Alternative_Cement_MF"]:
    Next_Use_data.loc['Concrete (w/ PC)', scenario] = MO_data.loc['Concrete (w/ PC)', scenario] * NU_Con
    Next_Use_data.loc['Iron/Steel', scenario] = MO_data.loc['Iron/Steel', scenario] * NU_Iron
    Next_Use_data.loc['Wood (Total)', scenario] = MO_data.loc['Wood (Total)', scenario] * NU_Wood
    Next_Use_data.loc['PC', scenario] = Next_Use_data.loc['Concrete (w/ PC)', scenario] * Cement_Mix

    Next_Use_data.loc['Total (Concrete+Iron+Wood)', scenario] = Next_Use_data.loc['Concrete (w/ PC)', scenario] + Next_Use_data.loc['Iron/Steel', scenario] + Next_Use_data.loc['Wood (Total)', scenario]
    Next_Use_data.loc['Total (PC+Iron+Wood)', scenario] = Next_Use_data.loc['PC', scenario] + Next_Use_data.loc['Iron/Steel', scenario] + Next_Use_data.loc['Wood (Total)', scenario]
    Next_Use_data.loc['Total (PC+AC+Iron+Wood)', scenario] =  Next_Use_data.loc['PC', scenario] + Next_Use_data.loc['Iron/Steel', scenario] + Next_Use_data.loc['Wood (Total)', scenario] + Next_Use_data.loc['AC', scenario]

# %%
# Make a loop for Next Use Total
for scenario in ['BAU2020_Total', 'BAU2040_Total', 'Compact_City_Total', 'Effective_Design_Total', 'Intensive_Use_Total', 'Mass_Timber_Total', 'Alternative_Cement_Total', "'+ Effective_Design_Total", "'+ Intensive_Use_Total", "'+ Mass_Timber_Total", "'+ Alternative_Cement_Total"]:
    if scenario == 'BAU2018_Total':
        SF_scenario = 'BAU2018_SF'
        MF_scenario = 'BAU2018_MF'
    elif scenario == 'BAU2020_Total':
        SF_scenario = 'BAU2020_SF'
        MF_scenario = 'BAU2020_MF'
    elif scenario == 'BAU2040_Total':
        SF_scenario = 'BAU2040_SF'
        MF_scenario = 'BAU2040_MF'
    elif scenario == 'BAU2040_Total':
        SF_scenario = 'BAU2040_SF'
        MF_scenario = 'BAU2040_MF'
    elif scenario == 'Compact_City_Total':
        SF_scenario = 'Compact_City_SF'
        MF_scenario = 'Compact_City_MF'
    elif scenario == 'Effective_Design_Total':
        SF_scenario = 'Effective_Design_SF'
        MF_scenario = 'Effective_Design_MF'    
    elif scenario == 'Intensive_Use_Total':
        SF_scenario = 'Intensive_Use_SF'
        MF_scenario = 'Intensive_Use_MF'  
    elif scenario == 'Mass_Timber_Total':
        SF_scenario = 'Mass_Timber_SF'
        MF_scenario = 'Mass_Timber_MF'  
    elif scenario == 'Alternative_Cement_Total':
        SF_scenario = 'Alternative_Cement_SF'
        MF_scenario = 'Alternative_Cement_MF'  
    elif scenario == "'+ Effective_Design_Total":
        SF_scenario = "'+ Effective_Design_SF"
        MF_scenario = "'+ Effective_Design_MF"  
    elif scenario == "'+ Intensive_Use_Total":
        SF_scenario = "'+ Intensive_Use_SF"
        MF_scenario = "'+ Intensive_Use_MF"  
    elif scenario == "'+ Mass_Timber_Total":
        SF_scenario = "'+ Mass_Timber_SF"
        MF_scenario = "'+ Mass_Timber_MF"  
    elif scenario == "'+ Alternative_Cement_Total":
        SF_scenario = "'+ Alternative_Cement_SF"
        MF_scenario = "'+ Alternative_Cement_MF"

    Next_Use_data[scenario] = Next_Use_data[SF_scenario] + Next_Use_data[MF_scenario]

# Make a loop for Annual Next Use
Next_Use_data['BAU2020_Annual'] = Next_Use_data['BAU2020_Total'] / 2

for scenario in ['BAU2040_Annual', 'Compact_City_Annual', 'Effective_Design_Annual', 'Intensive_Use_Annual', 'Mass_Timber_Annual', 'Alternative_Cement_Annual', "'+ Effective_Design_Annual", "'+ Intensive_Use_Annual", "'+ Mass_Timber_Annual", "'+ Alternative_Cement_Annual"]:
    if scenario == 'BAU2040_Annual':
        base_scenario = 'BAU2040_Total'
    elif scenario == 'Compact_City_Annual':
        base_scenario= 'Compact_City_Total'
    elif scenario == 'Effective_Design_Annual':
        base_scenario= 'Effective_Design_Total'
    elif scenario == 'Intensive_Use_Annual':
        base_scenario= 'Intensive_Use_Total'
    elif scenario == 'Mass_Timber_Annual':
        base_scenario= 'Mass_Timber_Total'
    elif scenario == 'Alternative_Cement_Annual':
        base_scenario= 'Alternative_Cement_Total'
    elif scenario == "'+ Effective_Design_Annual":
        base_scenario= "'+ Effective_Design_Total"
    elif scenario == "'+ Intensive_Use_Annual":
        base_scenario= "'+ Intensive_Use_Total"
    elif scenario == "'+ Mass_Timber_Annual":
        base_scenario= "'+ Mass_Timber_Total"
    elif scenario == "'+ Alternative_Cement_Annual":
        base_scenario= "'+ Alternative_Cement_Total"

    Next_Use_data[scenario] = Next_Use_data[base_scenario] / 22

Next_Use_data
# Out:
#                              BAU2020_SF   BAU2020_MF  BAU2020_Total  \
# Concrete (w/ PC)            1480.263325  2205.115985    3685.379310
# Iron/Steel                    78.947507   142.902121     221.849628
# Wood (Total)                 191.020046   664.582355     855.602401
# Wood (except CLT)              0.000000     0.000000       0.000000
# CLT                            0.000000     0.000000       0.000000
# PC                           186.513179   277.844614     464.357793
# Concrete (w/ AC)               0.000000     0.000000       0.000000
# AC                             0.000000     0.000000       0.000000
# Total (Concrete+Iron+Wood)  1750.230878  3012.600462    4762.831340
# Total (PC+Iron+Wood)         456.480732  1085.329091    1541.809823
# Total (PC+AC+Iron+Wood)      456.480732  1085.329091    1541.809823
#
#                             BAU2020_Annual    BAU2040_SF    BAU2040_MF  \
# Concrete (w/ PC)               1842.689655  16282.896341  24215.334584
# ...

# %%
Next_Use_data.to_csv('/Users/akihi/Library/CloudStorage/OneDrive-PrincetonUniversity/Projects/Building Material in Cities/1st Research/Code/Separated Code/MFA/Next Use.csv', index=True)
