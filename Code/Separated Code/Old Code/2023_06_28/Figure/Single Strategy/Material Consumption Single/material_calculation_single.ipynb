# %%
import matplotlib.pyplot as plt

# Data
strategies = ['BTU 2020', 'BTU 2040', '+ Compact City', '+ Effective Design', '+ Intensive Use', '+ Mass-Timber', 'Alternative Cement']
PC = [2705, 2665, 2646, 2158, 2132, 1849, 1396]

# Calculate reduction percentage
reduction_percentage = [100 * (PC[i] - PC[1]) / PC[1] for i in range(len(PC))]

# Define colors for each strategy
colors = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'grey']

# Create the bar graph
plt.bar(strategies, PC, color=colors)
plt.xlabel('Strategies')
plt.ylabel('Portland Cement PC in tons')
plt.title('Portland Cement PC Reduction Strategies')

# Add reduction percentage on top of each bar (excluding BTU 2020 and BTU 2040)
for i in range(2, len(PC)):
    plt.text(i, PC[i], f'{reduction_percentage[i]:.2f}%', ha='center', va='bottom')

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')

# Display the graph
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
strategies = ['BTU 2020', 'BTU 2040', '+ Compact City', '+ Effective Design', '+ Intensive Use', '+ Mass-Timber', 'Alternative Cement']
PC_AC = [2705, 2665, 2646, 2158, 2132, 1849, 2665]

# Calculate reduction percentage
reduction_percentage = [100 * (PC_AC[i] - PC_AC[1]) / PC_AC[1] for i in range(len(PC_AC))]

# Define colors for each strategy
colors = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'grey']

# Create the bar graph
plt.bar(strategies, PC_AC, color=colors)
plt.xlabel('Strategies')
plt.ylabel('Portland Cement PC_AC in tons')
plt.title('Portland Cement PC_AC')

# Add reduction percentage on top of each bar (excluding BTU 2020 and BTU 2040)
for i in range(2, len(PC_AC)):
    plt.text(i, PC_AC[i], f'{reduction_percentage[i]:.2f}%', ha='center', va='bottom')

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')

# Display the graph
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for PC graph
strategies_PC = ['BTU 2020', 'BTU 2040', '+ Compact City', '+ Effective Design', '+ Intensive Use', '+ Mass-Timber', 'Alternative Cement']
PC = [2705, 2665, 2646, 2158, 2132, 1849, 1396]

# Calculate reduction percentage for PC graph
reduction_percentage_PC = [100 * (PC[i] - PC[1]) / PC[1] for i in range(len(PC))]

# Define colors for PC graph
colors_PC = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'grey']

# Data for PC_AC graph
strategies_PC_AC = ['BTU 2020', 'BTU 2040', '+ Compact City', '+ Effective Design', '+ Intensive Use', '+ Mass-Timber', 'Alternative Cement']
PC_AC = [2705, 2665, 2646, 2158, 2132, 1849, 2665]

# Calculate reduction percentage for PC_AC graph
reduction_percentage_PC_AC = [100 * (PC_AC[i] - PC_AC[1]) / PC_AC[1] for i in range(len(PC_AC))]

# Define colors for PC_AC graph
colors_PC_AC = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'grey']

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot PC graph
ax1.bar(strategies_PC, PC, color=colors_PC)
ax1.set_xlabel('Strategies')
ax1.set_ylabel('Portland Cement PC in tons')
ax1.set_title('Portland Cement PC Reduction Strategies')

# Add reduction percentage on top of each bar for PC graph
for i in range(2, len(PC)):
    ax1.text(i, PC[i], f'{reduction_percentage_PC[i]:.2f}%', ha='center', va='bottom')

# Rotate x-axis labels for PC graph
ax1.set_xticklabels(strategies_PC, rotation=45, ha='right')

# Plot PC_AC graph
ax2.bar(strategies_PC_AC, PC_AC, color=colors_PC_AC)
ax2.set_xlabel('Strategies')
ax2.set_ylabel('Portland Cement PC_AC')
ax2.set_title('Portland Cement PC_AC Reduction Strategies')

# Add reduction percentage on top of each bar for PC_AC graph
for i in range(2, len(PC_AC)):
    ax2.text(i, PC_AC[i], f'{reduction_percentage_PC_AC[i]:.2f}%', ha='center', va='bottom')

# Rotate x-axis labels for PC_AC graph
ax2.set_xticklabels(strategies_PC_AC, rotation=45, ha='right')

# Adjust spacing between subplots
plt.tight_layout()

# Display the subplots
plt.show()
# Out:
# /var/folders/45/0prgpk010y5d3wglp3r_dz7r0000gn/T/ipykernel_25140/1644298225.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(strategies_PC, rotation=45, ha='right')
# /var/folders/45/0prgpk010y5d3wglp3r_dz7r0000gn/T/ipykernel_25140/1644298225.py:50: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(strategies_PC_AC, rotation=45, ha='right')

# %%
import matplotlib.pyplot as plt

# Data
strategies = ['BTU 2020', 'BTU 2040', '+ Compact City', '+ Effective Design', '+ Intensive Use', '+ Mass-Timber', 'Alternative Cement']
Iron_Steel = [1131, 1114, 1098, 1114, 892, 748, 1114]

# Calculate reduction percentage
reduction_percentage = [100 * (Iron_Steel[i] - Iron_Steel[1]) / Iron_Steel[1] for i in range(len(Iron_Steel))]

# Define colors for each strategy
colors = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'grey']

# Create the bar graph
plt.bar(strategies, Iron_Steel, color=colors)
plt.xlabel('Strategies')
plt.ylabel('Iron_Steel in tons')
plt.title('Iron Steel')

# Add reduction percentage on top of each bar (excluding BTU 2020 and BTU 2040)
for i in range(2, len(Iron_Steel)):
    plt.text(i, Iron_Steel[i], f'{reduction_percentage[i]:.2f}%', ha='center', va='bottom')

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')

# Display the graph
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
strategies = ['BTU 2020', 'BTU 2040', '+ Compact City', '+ Effective Design', '+ Intensive Use', '+ Mass-Timber', 'Alternative Cement']
Wood = [7252, 7146, 7027, 7146, 5717, 8215, 7146]

# Calculate reduction percentage
reduction_percentage = [100 * (Wood[i] - Wood[1]) / Wood[1] for i in range(len(Wood))]

# Define colors for each strategy
colors = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'grey']

# Create the bar graph
plt.bar(strategies, Wood, color=colors)
plt.xlabel('Strategies')
plt.ylabel('Wood in tons')
plt.title('Wood')

# Add reduction percentage on top of each bar (excluding BTU 2020 and BTU 2040)
for i in range(2, len(Wood)):
    plt.text(i, Wood[i], f'{reduction_percentage[i]:.2f}%', ha='center', va='bottom')

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')

# Set y-axis range
plt.ylim(0, 8700)
plt.yticks(range(0, 8001, 1000))

# Display the graph
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for PC graph
strategies_PC = ['BTU 2020', 'BTU 2040', 'Compact City', 'Effective Design', 'Intensive Use', 'Mass-Timber', 'Alternative Cement']
PC = [2705, 2665, 2646, 2158, 2132, 1849, 1396]

# Calculate reduction percentage for PC graph
reduction_percentage_PC = [100 * (PC[i] - PC[1]) / PC[1] for i in range(len(PC))]

# Define colors for PC graph
colors_PC = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'grey']

# Data for PC_AC graph
strategies_PC_AC = ['BTU 2020', 'BTU 2040', 'Compact City', 'Effective Design', 'Intensive Use', 'Mass-Timber', 'Alternative Cement']
PC_AC = [2705, 2665, 2646, 2158, 2132, 1849, 2665]

# Calculate reduction percentage for PC_AC graph
reduction_percentage_PC_AC = [100 * (PC_AC[i] - PC_AC[1]) / PC_AC[1] for i in range(len(PC_AC))]

# Define colors for PC_AC graph
colors_PC_AC = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'grey']

# Data for Iron_Steel graph
strategies_Iron_Steel = ['BTU 2020', 'BTU 2040', 'Compact City', 'Effective Design', 'Intensive Use', 'Mass-Timber', 'Alternative Cement']
Iron_Steel = [1131, 1114, 1098, 1114, 892, 748, 1114]

# Calculate reduction percentage for Iron_Steel graph
reduction_percentage_Iron_Steel = [100 * (Iron_Steel[i] - Iron_Steel[1]) / Iron_Steel[1] for i in range(len(Iron_Steel))]

# Define colors for Iron_Steel graph
colors_Iron_Steel = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'grey']

# Data for Wood graph
strategies_Wood = ['BTU 2020', 'BTU 2040', 'Compact City', 'Effective Design', 'Intensive Use', 'Mass-Timber', 'Alternative Cement']
Wood = [7252, 7146, 7027, 7146, 5717, 8215, 7146]

# Calculate reduction percentage for Wood graph
reduction_percentage_Wood = [100 * (Wood[i] - Wood[1]) / Wood[1] for i in range(len(Wood))]

# Define colors for Wood graph
colors_Wood = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'grey']

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Plot PC graph
axs[0, 0].bar(strategies_PC, PC, color=colors_PC)
#axs[0, 0].set_xlabel('Strategies')
axs[0, 0].set_ylabel('Portland Cement in tons')
axs[0, 0].set_title('Portland Cement')


# Add reduction percentage on top of each bar in PC graph (excluding BTU 2020 and BTU 2040)
for i in range(2, len(PC)):
    axs[0, 0].text(i, PC[i], f'{reduction_percentage_PC[i]:.2f}%', ha='center', va='bottom')

# Rotate x-axis labels in PC graph
axs[0, 0].set_xticklabels(strategies_PC, rotation=45, ha='right')

# Plot PC_AC graph
axs[0, 1].bar(strategies_PC_AC, PC_AC, color=colors_PC_AC)
#axs[0, 1].set_xlabel('Strategies')
axs[0, 1].set_ylabel('PC & Alternative Cement in tons')
axs[0, 1].set_title('PC & Alternative Cement')

# Add reduction percentage on top of each bar in PC_AC graph (excluding BTU 2020 and BTU 2040)
for i in range(2, len(PC_AC)):
    axs[0, 1].text(i, PC_AC[i], f'{reduction_percentage_PC_AC[i]:.2f}%', ha='center', va='bottom')

# Rotate x-axis labels in PC_AC graph
axs[0, 1].set_xticklabels(strategies_PC_AC, rotation=45, ha='right')

# Plot Iron_Steel graph
axs[1, 0].bar(strategies_Iron_Steel, Iron_Steel, color=colors_Iron_Steel)
#axs[1, 0].set_xlabel('Strategies')
axs[1, 0].set_ylabel('Iron Steel in tons')
axs[1, 0].set_title('Iron Steel')

# Add reduction percentage on top of each bar in Iron_Steel graph (excluding BTU 2020 and BTU 2040)
for i in range(2, len(Iron_Steel)):
    axs[1, 0].text(i, Iron_Steel[i], f'{reduction_percentage_Iron_Steel[i]:.2f}%', ha='center', va='bottom')

# Rotate x-axis labels in Iron_Steel graph
axs[1, 0].set_xticklabels(strategies_Iron_Steel, rotation=45, ha='right')

# Plot Wood graph
axs[1, 1].bar(strategies_Wood, Wood, color=colors_Wood)
#axs[1, 1].set_xlabel('Strategies')
axs[1, 1].set_ylabel('Wood in tons')
axs[1, 1].set_title('Wood')

# Add reduction percentage on top of each bar in Wood graph (excluding BTU 2020 and BTU 2040)
for i in range(2, len(Wood)):
    axs[1, 1].text(i, Wood[i], f'{reduction_percentage_Wood[i]:.2f}%', ha='center', va='bottom')

# Rotate x-axis labels in Wood graph
axs[1, 1].set_xticklabels(strategies_Wood, rotation=45, ha='right')

# Set y-axis range of wood graph
axs[1, 1].set_ylim(0, 8700)
axs[1, 1].set_yticks(range(0, 8001, 1000))

# Adjust spacing between subplots
plt.tight_layout()


#plt.savefig('/Users/akihi/Library/CloudStorage/OneDrive-PrincetonUniversity/Projects/Building Material in Cities/Code/Material Consumption/Material Consumption.png')
# Out:
# /var/folders/45/0prgpk010y5d3wglp3r_dz7r0000gn/T/ipykernel_25140/1982526410.py:58: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 0].set_xticklabels(strategies_PC, rotation=45, ha='right')
# /var/folders/45/0prgpk010y5d3wglp3r_dz7r0000gn/T/ipykernel_25140/1982526410.py:71: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 1].set_xticklabels(strategies_PC_AC, rotation=45, ha='right')
# /var/folders/45/0prgpk010y5d3wglp3r_dz7r0000gn/T/ipykernel_25140/1982526410.py:84: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1, 0].set_xticklabels(strategies_Iron_Steel, rotation=45, ha='right')
# /var/folders/45/0prgpk010y5d3wglp3r_dz7r0000gn/T/ipykernel_25140/1982526410.py:97: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1, 1].set_xticklabels(strategies_Wood, rotation=45, ha='right')

# %%
import matplotlib.pyplot as plt

# Data for PC graph
strategies_PC = ['BAU 2020', 'BAU 2040', 'Compact City', 'Effective Design', 'Intensive Use', 'Mass-Timber', 'Alternative Cement']
PC = [2755, 2715, 2671, 2199, 2172, 1899, 1446]

# Calculate reduction percentage for PC graph
reduction_percentage_PC = [100 * (PC[i] - PC[1]) / PC[1] for i in range(len(PC))]

# Define colors for PC graph
colors_PC = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'grey']

# Data for Iron_Steel graph
strategies_Iron_Steel = ['BAU 2020', 'BAU 2040', 'Compact City', 'Effective Design', 'Intensive Use', 'Mass-Timber', 'Alternative Cement']
Iron_Steel = [1134, 1118, 1100, 1118, 894, 752, 1118]

# Calculate reduction percentage for Iron_Steel graph
reduction_percentage_Iron_Steel = [100 * (Iron_Steel[i] - Iron_Steel[1]) / Iron_Steel[1] for i in range(len(Iron_Steel))]

# Define colors for Iron_Steel graph
colors_Iron_Steel = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'grey']

# Data for Wood graph
strategies_Wood = ['BAU 2020', 'BAU 2040', 'Compact City', 'Effective Design', 'Intensive Use', 'Mass-Timber', 'Alternative Cement']
Wood = [7242, 7136, 7022, 7136, 5709, 8205, 7136]

# Calculate reduction percentage for Wood graph
reduction_percentage_Wood = [100 * (Wood[i] - Wood[1]) / Wood[1] for i in range(len(Wood))]

# Define colors for Wood graph
colors_Wood = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'grey']

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(12, 8))

# Plot PC graph
axs[0].bar(strategies_PC, PC, color=colors_PC)
#axs[0].set_xlabel('Strategies')
axs[0].set_ylabel('Portland Cement in tons')
axs[0].set_title('Portland Cement')


# Add reduction percentage on top of each bar in PC graph (excluding BTU 2020 and BTU 2040)
for i in range(2, len(PC)):
    axs[0].text(i, PC[i], f'{reduction_percentage_PC[i]:.2f}%', ha='center', va='bottom')

# Rotate x-axis labels in PC graph
axs[0].set_xticklabels(strategies_PC, rotation=45, ha='right')

# Plot Iron_Steel graph
axs[1].bar(strategies_Iron_Steel, Iron_Steel, color=colors_Iron_Steel)
#axs[1].set_xlabel('Strategies')
axs[1].set_ylabel('Iron Steel in tons')
axs[1].set_title('Iron Steel')

# Add reduction percentage on top of each bar in Iron_Steel graph (excluding BTU 2020 and BTU 2040)
for i in range(2, len(Iron_Steel)):
    axs[1].text(i, Iron_Steel[i], f'{reduction_percentage_Iron_Steel[i]:.2f}%', ha='center', va='bottom')

# Rotate x-axis labels in Iron_Steel graph
axs[1].set_xticklabels(strategies_Iron_Steel, rotation=45, ha='right')

# Plot Wood graph
axs[2].bar(strategies_Wood, Wood, color=colors_Wood)
#axs[2].set_xlabel('Strategies')
axs[2].set_ylabel('Wood in tons')
axs[2].set_title('Wood')

# Add reduction percentage on top of each bar in Wood graph (excluding BTU 2020 and BTU 2040)
for i in range(2, len(Wood)):
    axs[2].text(i, Wood[i], f'{reduction_percentage_Wood[i]:.2f}%', ha='center', va='bottom')

# Rotate x-axis labels in Wood graph
axs[2].set_xticklabels(strategies_Wood, rotation=45, ha='right')

# Set y-axis range of wood graph
axs[2].set_ylim(0, 8700)
axs[2].set_yticks(range(0, 8001, 1000))

# Adjust spacing between subplots
plt.tight_layout()


#plt.savefig('/Users/akihi/Library/CloudStorage/OneDrive-PrincetonUniversity/Projects/Building Material in Cities/Code/Material Consumption/Material Consumption.png')
# Out:
# /var/folders/45/0prgpk010y5d3wglp3r_dz7r0000gn/T/ipykernel_25140/1490956360.py:48: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels(strategies_PC, rotation=45, ha='right')
# /var/folders/45/0prgpk010y5d3wglp3r_dz7r0000gn/T/ipykernel_25140/1490956360.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_xticklabels(strategies_Iron_Steel, rotation=45, ha='right')
# /var/folders/45/0prgpk010y5d3wglp3r_dz7r0000gn/T/ipykernel_25140/1490956360.py:74: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[2].set_xticklabels(strategies_Wood, rotation=45, ha='right')
